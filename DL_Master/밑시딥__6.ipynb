# %% [markdown]
# <a href="https://colab.research.google.com/github/comandi1969/AIFFEL_Online_Quest/blob/main/DL_Master/%EB%B0%91%EC%8B%9C%EB%94%A5__6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class SGD:
    def __init__(self, lr=0.01):
        self.lr = lr

    def update(self, params, grads):
        for key in params.keys():
            params[key] -= self.lr * grads[key]

# %%
# 그림 6-1 f(x, y) = (1/20) * x**2 + y**2 그래프
# 3차원 참고주소: https://www.datascienceschool.net/view-notebook/6e71dbff254542d9b0a054a7c98b34ec/
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Define the function
def f(x, y):
    return (1 / 20) * x**2 + y**2

# Generate x and y data points
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
Z = f(X, Y)

# Create 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the surface
ax.plot_surface(X, Y, Z, cmap='viridis')

# Set labels and title
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('f(X, Y)')
ax.set_title('3D Graph of f(X, Y) = (1 / 20) * X^2 + Y^2')

# Show the plot
plt.show()

# %%
# 그림 6-1 f(x, y) = (1/20) * x**2 + y**2 등고선
plt.contour(X, Y, Z, 100, colors='k')
plt.ylim(-10, 10)
plt.xlim(-10, 10)
# Out:
# (-10.0, 10.0)

# %%
def _numerical_gradient_no_batch(f, x):
    h = 1e-4 # 0.0001
    grad = np.zeros_like(x) # x와 형상이 같은 배열을 생성

    for idx in range(x.size):
        tmp_val = x[idx]

        # f(x+h) 계산
        x[idx] = float(tmp_val) + h
        fxh1 = f(x)

        # f(x-h) 계산
        x[idx] = tmp_val - h
        fxh2 = f(x)

        grad[idx] = (fxh1 - fxh2) / (2*h)
        x[idx] = tmp_val # 값 복원

    return grad

# %%
# 그림 6-2 f(x, y) = (1/20) * x**2 + y**2 의 기울기
# https://github.com/WegraLee/deep-learning-from-scratch/blob/master/ch04/gradient_2d.py 소스 참고
from mpl_toolkits.mplot3d import Axes3D

def numerical_gradient(f, X):
    if X.ndim == 1:
        return _numerical_gradient_no_batch(f, X)
    else:
        grad = np.zeros_like(X)

        for idx, x in enumerate(X):
            grad[idx] = _numerical_gradient_no_batch(f, x)

        return grad

def function_2(x):
    if x.ndim == 1:
        return np.sum(x**2)
    else:
        return np.sum(x**2, axis=1)

x0 = np.arange(-10, 10, 1)
x1 = np.arange(-10, 10, 1)
X, Y = np.meshgrid(x0, x1)

X = X.flatten()
Y = Y.flatten()

grad = numerical_gradient(function_2, np.array([(1/(20**0.5))*X, Y]) )

plt.figure()
plt.quiver(X, Y, -grad[0], -grad[1],  angles="xy",color="#666666")#,headwidth=10,scale=40,color="#444444")
plt.xlim([-10, 10])
plt.ylim([-5, 5])
plt.xlabel('x0')
plt.ylabel('x1')
plt.grid()
plt.legend()
plt.draw()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
class Momentum:
    def __init__(self, lr=0.01, momentum=0.9):
        self.lr = lr
        self.momentum = momentum
        self.v = None

    def update(self, params, grads):
        if self.v is None:
            self.v = {}
            for key, val in params.items():
                self.v[key] = np.zeros_like(val)

        for key in params.keys():
            self.v[key] = self.momentum*self.v[key] - self.lr*grads[key]
            params[key] += self.v[key]

# %%
class AdaGrad:
    def __init__(self, lr=0.01):
        self.lr = lr
        self.h = None

    def update(self, params, grads):
        if self.h is None:
            self.h = {}
            for key, val in params.items():
                self.h[key] = np.zeros_like(val)

        for key in params.keys():
            self.h[key] += grads[key] * grads[key]
            params[key] -= self.lr * grads[key] / (np.sqrt(self.h[key]) + 1e-7)

# %%
# https://github.com/WegraLee/deep-learning-from-scratch/blob/master/common/optimizer.py 참고
class Adam:

    """Adam (http://arxiv.org/abs/1412.6980v8)"""

    def __init__(self, lr=0.001, beta1=0.9, beta2=0.999):
        self.lr = lr
        self.beta1 = beta1
        self.beta2 = beta2
        self.iter = 0
        self.m = None
        self.v = None

    def update(self, params, grads):
        if self.m is None:
            self.m, self.v = {}, {}
            for key, val in params.items():
                self.m[key] = np.zeros_like(val)
                self.v[key] = np.zeros_like(val)

        self.iter += 1
        lr_t  = self.lr * np.sqrt(1.0 - self.beta2**self.iter) / (1.0 - self.beta1**self.iter)

        for key in params.keys():
            #self.m[key] = self.beta1*self.m[key] + (1-self.beta1)*grads[key]
            #self.v[key] = self.beta2*self.v[key] + (1-self.beta2)*(grads[key]**2)
            self.m[key] += (1 - self.beta1) * (grads[key] - self.m[key])
            self.v[key] += (1 - self.beta2) * (grads[key]**2 - self.v[key])

            params[key] -= lr_t * self.m[key] / (np.sqrt(self.v[key]) + 1e-7)

            #unbias_m += (1 - self.beta1) * (grads[key] - self.m[key]) # correct bias
            #unbisa_b += (1 - self.beta2) * (grads[key]*grads[key] - self.v[key]) # correct bias
            #params[key] += self.lr * unbias_m / (np.sqrt(unbisa_b) + 1e-7)

# %%
# https://github.com/WegraLee/deep-learning-from-scratch/blob/master/ch06/optimizer_compare_naive.py 참고
# coding: utf-8
import numpy as np
import matplotlib.pyplot as plt
from collections import OrderedDict

def f(x, y):
    return x**2 / 20.0 + y**2

def df(x, y):
    return x / 10.0, 2.0*y

init_pos = (-7.0, 2.0)
params = {}
params['x'], params['y'] = init_pos[0], init_pos[1]
grads = {}
grads['x'], grads['y'] = 0, 0


optimizers = OrderedDict()
optimizers["SGD"] = SGD(lr=0.95)
optimizers["Momentum"] = Momentum(lr=0.1)
optimizers["AdaGrad"] = AdaGrad(lr=1.5)
optimizers["Adam"] = Adam(lr=0.3)

idx = 1

for key in optimizers:
    optimizer = optimizers[key]
    x_history = []
    y_history = []
    params['x'], params['y'] = init_pos[0], init_pos[1]

    for i in range(30):
        x_history.append(params['x'])
        y_history.append(params['y'])

        grads['x'], grads['y'] = df(params['x'], params['y'])
        optimizer.update(params, grads)


    x = np.arange(-10, 10, 0.01)
    y = np.arange(-5, 5, 0.01)

    X, Y = np.meshgrid(x, y)
    Z = f(X, Y)

    # 외곽선 단순화
    mask = Z > 7
    Z[mask] = 0

    # 그래프 그리기
    plt.subplot(2, 2, idx)
    idx += 1
    plt.plot(x_history, y_history, 'o-', color="red")
    plt.contour(X, Y, Z)
    plt.ylim(-10, 10)
    plt.xlim(-10, 10)
    plt.plot(0, 0, '+')
    #colorbar()
    #spring()
    plt.title(key)
    plt.xlabel("x")
    plt.ylabel("y")

plt.show()

# %%
# https://github.com/WegraLee/deep-learning-from-scratch/blob/master/ch06/optimizer_compare_mnist.py 참고
# coding: utf-8
#import os
#import sys
#sys.path.append(os.pardir)  # 부모 디렉터리의 파일을 가져올 수 있도록 설정
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.util import smooth_curve
from common.multi_layer_net import MultiLayerNet
#from common.optimizer import *

# 0. MNIST 데이터 읽기==========
(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

train_size = x_train.shape[0]
batch_size = 128
max_iterations = 2000

# 1. 실험용 설정==========
optimizers = {}
optimizers['SGD'] = SGD()
optimizers['Momentum'] = Momentum()
optimizers['AdaGrad'] = AdaGrad()
optimizers['Adam'] = Adam()
#optimizers['RMSprop'] = RMSprop()

networks = {}
train_loss = {}
for key in optimizers.keys():
    networks[key] = MultiLayerNet(
        input_size=784, hidden_size_list=[100, 100, 100, 100],
        output_size=10)
    train_loss[key] = []

# 2. 훈련 시작==========
for i in range(max_iterations):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]

    for key in optimizers.keys():
        grads = networks[key].gradient(x_batch, t_batch)
        optimizers[key].update(networks[key].params, grads)

        loss = networks[key].loss(x_batch, t_batch)
        train_loss[key].append(loss)

    if i % 100 == 0:
        print( "===========" + "iteration:" + str(i) + "===========")
        for key in optimizers.keys():
            loss = networks[key].loss(x_batch, t_batch)
            print(key + ":" + str(loss))

# 3. 그래프 그리기==========
markers = {"SGD": "o", "Momentum": "x", "AdaGrad": "s", "Adam": "D"}
x = np.arange(max_iterations)
for key in optimizers.keys():
    plt.plot(x, smooth_curve(train_loss[key]), marker=markers[key], markevery=100, label=key)
plt.xlabel("iterations")
plt.ylabel("loss")
plt.ylim(0, 1)
plt.legend()
plt.show()
# Out:
# ===========iteration:0===========
# SGD:2.3773769298027663
# Momentum:2.384541975776643
# AdaGrad:2.1282189797632203
# Adam:2.2131138331743436
# ===========iteration:100===========
# SGD:1.3428309200259538
# Momentum:0.36587418763131824
# AdaGrad:0.14734617325293328
# Adam:0.30207751209995465
# ===========iteration:200===========
# SGD:0.7786679684140582
# Momentum:0.44790108110000826
# AdaGrad:0.11888461417654538
# Adam:0.37856162795570425
# ===========iteration:300===========
# SGD:0.5627112395686128
# Momentum:0.2716081343845972
# AdaGrad:0.09844732713017632
# Adam:0.15052489839838168
# ===========iteration:400===========
# SGD:0.41577869124275246
# Momentum:0.23977644053857564
# AdaGrad:0.09471837236890784
# Adam:0.16555479284227936
# ===========iteration:500===========
# SGD:0.2578273954525785
# Momentum:0.09518759789537246
# AdaGrad:0.043938218771449156
# Adam:0.07570392538649642
# ===========iteration:600===========
# SGD:0.3740603815274509
# Momentum:0.1998999115399195
# AdaGrad:0.08856714602164037
# Adam:0.11669457071048711
# ===========iteration:700===========
# SGD:0.27627213386222244
# Momentum:0.10142163994759815
# AdaGrad:0.04751128568774784
# Adam:0.10863452668791142
# ===========iteration:800===========
# SGD:0.3859349204051302
# Momentum:0.1762352988349406
# AdaGrad:0.06249939424934122
# Adam:0.1222948646055287
# ===========iteration:900===========
# SGD:0.2662692619043485
# Momentum:0.11413418922020141
# AdaGrad:0.07426344567726333
# Adam:0.11124085483535864
# ===========iteration:1000===========
# SGD:0.2879717147855604
# Momentum:0.1798208867662142
# AdaGrad:0.07048936687077187
# Adam:0.08729947437459532
# ===========iteration:1100===========
# SGD:0.2641702126209141
# Momentum:0.06080899983825483
# AdaGrad:0.030932225802465955
# Adam:0.03546369344790665
# ===========iteration:1200===========
# SGD:0.22819103388837828
# Momentum:0.10866709262672569
# AdaGrad:0.06068606840739592
# Adam:0.09205098645219123
# ===========iteration:1300===========
# SGD:0.29586543755464123
# Momentum:0.16110417625423412
# AdaGrad:0.12531175743367137
# Adam:0.12799318736546914
# ===========iteration:1400===========
# SGD:0.2666604491669874
# Momentum:0.09609523714876061
# AdaGrad:0.04223485079991421
# Adam:0.08153449289831788
# ===========iteration:1500===========
# SGD:0.2243135982124485
# Momentum:0.04766407469747977
# AdaGrad:0.020461617441984523
# Adam:0.03144912386199026
# ===========iteration:1600===========
# SGD:0.1841377924462676
# Momentum:0.05121786669491108
# AdaGrad:0.03027146462493844
# Adam:0.04223296501770115
# ===========iteration:1700===========
# SGD:0.20645693520014252
# Momentum:0.0904024658142242
# AdaGrad:0.020092526677810002
# Adam:0.044901552259027304
# ===========iteration:1800===========
# SGD:0.23122094507659122
# Momentum:0.11168846243703362
# AdaGrad:0.06125519416096023
# Adam:0.12207338246467903
# ===========iteration:1900===========
# SGD:0.25119466692055187
# Momentum:0.1241006405812227
# AdaGrad:0.052000628883879574
# Adam:0.0611487371193208

# %%
# https://github.com/WegraLee/deep-learning-from-scratch/blob/master/ch06/weight_init_activation_histogram.py 참고
# coding: utf-8
import numpy as np
import matplotlib.pyplot as plt

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def ReLU(x):
    return np.maximum(0, x)

def tanh(x):
    return np.tanh(x)

input_data = np.random.randn(1000, 100)  # 1000개의 데이터
node_num = 100  # 각 은닉층의 노드(뉴런) 수
hidden_layer_size = 5  # 은닉층이 5개
activations = {}  # 이곳에 활성화 결과를 저장

x = input_data

def get_activation(hidden_layer_size, x, w, a_func=sigmoid):
    for i in range(hidden_layer_size):
        if i != 0:
            x = activations[i-1]

        a = np.dot(x, w)

        # 활성화 함수도 바꿔가며 실험해보자！
        z = a_func(a)
        # z = ReLU(a)
        # z = tanh(a)

        activations[i] = z
    return activations

# 초깃값을 다양하게 바꿔가며 실험해보자！
w = np.random.randn(node_num, node_num) * 1
#w= np.random.randn(node_num, node_num) * 0.01
w = np.random.randn(node_num, node_num) * np.sqrt(1.0 / node_num) # Xavier
#w = np.random.randn(node_num, node_num) * np.sqrt(2.0 / node_num) # He

z = sigmoid
#z = ReLU
#z = tanh

activations = get_activation(hidden_layer_size, x, w, z)

# %%
# 히스토그램 그리기
def get_histogram(activations):
    for i, a in activations.items():
        plt.subplot(1, len(activations), i+1)
        plt.title(str(i+1) + "-layer")
        if i != 0: plt.yticks([], [])
        # plt.xlim(0.1, 1)
        # plt.ylim(0, 7000)
        plt.hist(a.flatten(), 30, range=(0,1))
    plt.show()

get_histogram(activations)

# %%
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.util import smooth_curve
from common.multi_layer_net import MultiLayerNet
#from common.optimizer import SGD


# 0. MNIST 데이터 읽기==========
(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

train_size = x_train.shape[0]
batch_size = 128
max_iterations = 2000


# 1. 실험용 설정==========
weight_init_types = {'std=0.01': 0.01, 'Xavier': 'sigmoid', 'He': 'relu'}
optimizer = SGD(lr=0.01)

networks = {}
train_loss = {}
for key, weight_type in weight_init_types.items():
    networks[key] = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100],
                                  output_size=10, weight_init_std=weight_type)
    train_loss[key] = []


# 2. 훈련 시작==========
for i in range(max_iterations):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]

    for key in weight_init_types.keys():
        grads = networks[key].gradient(x_batch, t_batch)
        optimizer.update(networks[key].params, grads)

        loss = networks[key].loss(x_batch, t_batch)
        train_loss[key].append(loss)

    if i % 100 == 0:
        print("===========" + "iteration:" + str(i) + "===========")
        for key in weight_init_types.keys():
            loss = networks[key].loss(x_batch, t_batch)
            print(key + ":" + str(loss))


# 3. 그래프 그리기==========
markers = {'std=0.01': 'o', 'Xavier': 's', 'He': 'D'}
x = np.arange(max_iterations)
for key in weight_init_types.keys():
    plt.plot(x, smooth_curve(train_loss[key]), marker=markers[key], markevery=100, label=key)
plt.xlabel("iterations")
plt.ylabel("loss")
plt.ylim(0, 2.5)
plt.legend()
plt.show()
# Out:
# ===========iteration:0===========
# std=0.01:2.3024110398258064
# Xavier:2.3066874776393167
# He:2.5385819703111934
# ===========iteration:100===========
# std=0.01:2.3016404848635332
# Xavier:2.232556361014705
# He:1.571184596554923
# ===========iteration:200===========
# std=0.01:2.302159715316226
# Xavier:2.0787348121325957
# He:0.7490883330189397
# ===========iteration:300===========
# std=0.01:2.2997675327498257
# Xavier:1.574702094000293
# He:0.5009633488239895
# ===========iteration:400===========
# std=0.01:2.2997893714037483
# Xavier:1.0658158089500234
# He:0.44021711169189626
# ===========iteration:500===========
# std=0.01:2.3008348967782863
# Xavier:0.7296201766892833
# He:0.30499465287849514
# ===========iteration:600===========
# std=0.01:2.302165331172305
# Xavier:0.5977881086099786
# He:0.30039708285866484
# ===========iteration:700===========
# std=0.01:2.3035598214397206
# Xavier:0.4600282861540381
# He:0.3002961035257608
# ===========iteration:800===========
# std=0.01:2.302272344917185
# Xavier:0.4911924508716402
# He:0.3313828565424265
# ===========iteration:900===========
# std=0.01:2.3055335570712
# Xavier:0.3334461910652087
# He:0.1831289097746665
# ===========iteration:1000===========
# std=0.01:2.2964953931526404
# Xavier:0.3982690204705998
# He:0.2538593016558469
# ===========iteration:1100===========
# std=0.01:2.301353146611601
# Xavier:0.4696955663647029
# He:0.4184736007915467
# ===========iteration:1200===========
# std=0.01:2.3044803734611294
# Xavier:0.3550616585517934
# He:0.25362481150464533
# ===========iteration:1300===========
# std=0.01:2.2973862938472385
# Xavier:0.30233239149589963
# He:0.2466725736014775
# ===========iteration:1400===========
# std=0.01:2.302853166868295
# Xavier:0.38683774220486955
# He:0.28106134825745444
# ===========iteration:1500===========
# std=0.01:2.2961211634650187
# Xavier:0.2305598118314163
# He:0.17431153848440012
# ===========iteration:1600===========
# std=0.01:2.293227950670141
# Xavier:0.2407965369722483
# He:0.13175036010585822
# ===========iteration:1700===========
# std=0.01:2.29831132687245
# Xavier:0.2646957893005934
# He:0.25201209376656486
# ===========iteration:1800===========
# std=0.01:2.3022190350778997
# Xavier:0.2274662700640164
# He:0.17434886874800298
# ===========iteration:1900===========
# std=0.01:2.302726450119584
# Xavier:0.2499622270538328
# He:0.20261410973802355

# %%
# https://github.com/WegraLee/deep-learning-from-scratch/blob/master/ch06/batch_norm_test.py 참고
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net_extend import MultiLayerNetExtend
#from common.optimizer import SGD, Adam

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 학습 데이터를 줄임
x_train = x_train[:1000]
t_train = t_train[:1000]

max_epochs = 20
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.01


def __train(weight_init_std):
    bn_network = MultiLayerNetExtend(input_size=784, hidden_size_list=[100, 100, 100, 100, 100], output_size=10,
                                    weight_init_std=weight_init_std, use_batchnorm=True)
    network = MultiLayerNetExtend(input_size=784, hidden_size_list=[100, 100, 100, 100, 100], output_size=10,
                                weight_init_std=weight_init_std)
    optimizer = SGD(lr=learning_rate)

    train_acc_list = []
    bn_train_acc_list = []

    iter_per_epoch = max(train_size / batch_size, 1)
    epoch_cnt = 0

    for i in range(1000000000):
        batch_mask = np.random.choice(train_size, batch_size)
        x_batch = x_train[batch_mask]
        t_batch = t_train[batch_mask]

        for _network in (bn_network, network):
            grads = _network.gradient(x_batch, t_batch)
            optimizer.update(_network.params, grads)

        if i % iter_per_epoch == 0:
            train_acc = network.accuracy(x_train, t_train)
            bn_train_acc = bn_network.accuracy(x_train, t_train)
            train_acc_list.append(train_acc)
            bn_train_acc_list.append(bn_train_acc)

            #print("epoch:" + str(epoch_cnt) + " | " + str(train_acc) + " - " + str(bn_train_acc))

            epoch_cnt += 1
            if epoch_cnt >= max_epochs:
                break

    return train_acc_list, bn_train_acc_list


# 그래프 그리기==========
weight_scale_list = np.logspace(0, -4, num=16)
x = np.arange(max_epochs)

for i, w in enumerate(weight_scale_list):
    #print( "============== " + str(i+1) + "/16" + " ==============")
    train_acc_list, bn_train_acc_list = __train(w)

    plt.subplot(4,4,i+1)
    plt.title("W:" + str(w))
    if i == 15:
        plt.plot(x, bn_train_acc_list, label='Batch Normalization', markevery=2)
        plt.plot(x, train_acc_list, linestyle = "--", label='Normal(without BatchNorm)', markevery=2)
    else:
        plt.plot(x, bn_train_acc_list, markevery=2)
        plt.plot(x, train_acc_list, linestyle="--", markevery=2)

    plt.ylim(0, 1.0)
    if i % 4:
        plt.yticks([])
    else:
        plt.ylabel("accuracy")
    if i < 12:
        plt.xticks([])
    else:
        plt.xlabel("epochs")
    plt.legend(loc='lower right')

plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# /content/common/functions.py:34: RuntimeWarning: invalid value encountered in subtract
#   x = x - np.max(x, axis=0)
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import numpy as np
import matplotlib.pyplot as plt
from common.multi_layer_net import MultiLayerNet
#from common.optimizer import SGD

# https://github.com/WegraLee/deep-learning-from-scratch/blob/master/ch06/overfit_weight_decay.py 참고
from dataset.mnist import load_mnist

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)
# 오버피팅을 재현하기 위해 학습 데이터 수를 줄임
x_train = x_train[:300]
t_train = t_train[:300]

# weight decay（가중치 감쇠） 설정 =======================
weight_decay_lambda = 0 # weight decay를 사용하지 않을 경우
#weight_decay_lambda = 0.1
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10,
                        weight_decay_lambda=weight_decay_lambda)
optimizer = SGD(lr=0.01) # 학습률이 0.01인 SGD로 매개변수 갱신

max_epochs = 201
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
train_acc_list = []
test_acc_list = []

iter_per_epoch = max(train_size / batch_size, 1)
epoch_cnt = 0

for i in range(1000000000):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]

    grads = network.gradient(x_batch, t_batch)
    optimizer.update(network.params, grads)

    if i % iter_per_epoch == 0:
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list.append(train_acc)
        test_acc_list.append(test_acc)

        print("epoch:" + str(epoch_cnt) + ", train acc:" + str(train_acc) + ", test acc:" + str(test_acc))

        epoch_cnt += 1
        if epoch_cnt >= max_epochs:
            break
# Out:
# epoch:0, train acc:0.07333333333333333, test acc:0.095
# epoch:1, train acc:0.07666666666666666, test acc:0.0955
# epoch:2, train acc:0.07666666666666666, test acc:0.0973
# epoch:3, train acc:0.10333333333333333, test acc:0.0996
# epoch:4, train acc:0.11666666666666667, test acc:0.1052
# epoch:5, train acc:0.13333333333333333, test acc:0.1124
# epoch:6, train acc:0.16666666666666666, test acc:0.128
# epoch:7, train acc:0.18333333333333332, test acc:0.1381
# epoch:8, train acc:0.21666666666666667, test acc:0.1578
# epoch:9, train acc:0.2633333333333333, test acc:0.1761
# epoch:10, train acc:0.31333333333333335, test acc:0.2198
# epoch:11, train acc:0.3433333333333333, test acc:0.2452
# epoch:12, train acc:0.37, test acc:0.2625
# epoch:13, train acc:0.41333333333333333, test acc:0.2796
# epoch:14, train acc:0.4066666666666667, test acc:0.2946
# epoch:15, train acc:0.42, test acc:0.3061
# epoch:16, train acc:0.43333333333333335, test acc:0.3122
# epoch:17, train acc:0.44666666666666666, test acc:0.3201
# epoch:18, train acc:0.4666666666666667, test acc:0.3299
# epoch:19, train acc:0.4666666666666667, test acc:0.3355
# epoch:20, train acc:0.46, test acc:0.3326
# epoch:21, train acc:0.47, test acc:0.3392
# epoch:22, train acc:0.47333333333333333, test acc:0.3413
# epoch:23, train acc:0.4666666666666667, test acc:0.3457
# epoch:24, train acc:0.49, test acc:0.3576
# epoch:25, train acc:0.5133333333333333, test acc:0.3724
# epoch:26, train acc:0.5333333333333333, test acc:0.3749
# epoch:27, train acc:0.5633333333333334, test acc:0.3945
# epoch:28, train acc:0.5866666666666667, test acc:0.4095
# epoch:29, train acc:0.6033333333333334, test acc:0.4244
# epoch:30, train acc:0.61, test acc:0.4407
# epoch:31, train acc:0.6533333333333333, test acc:0.4561
# epoch:32, train acc:0.6466666666666666, test acc:0.47
# epoch:33, train acc:0.6866666666666666, test acc:0.4904
# epoch:34, train acc:0.6933333333333334, test acc:0.5112
# epoch:35, train acc:0.6966666666666667, test acc:0.5097
# epoch:36, train acc:0.7066666666666667, test acc:0.5231
# epoch:37, train acc:0.7233333333333334, test acc:0.5432
# epoch:38, train acc:0.72, test acc:0.5462
# epoch:39, train acc:0.73, test acc:0.5586
# epoch:40, train acc:0.7433333333333333, test acc:0.5687
# epoch:41, train acc:0.75, test acc:0.5765
# epoch:42, train acc:0.7666666666666667, test acc:0.5892
# epoch:43, train acc:0.7733333333333333, test acc:0.5953
# epoch:44, train acc:0.7733333333333333, test acc:0.6069
# epoch:45, train acc:0.78, test acc:0.6091
# epoch:46, train acc:0.8066666666666666, test acc:0.6117
# epoch:47, train acc:0.7933333333333333, test acc:0.6217
# epoch:48, train acc:0.8033333333333333, test acc:0.6189
# epoch:49, train acc:0.8133333333333334, test acc:0.6293
# epoch:50, train acc:0.81, test acc:0.6378
# epoch:51, train acc:0.8166666666666667, test acc:0.6432
# epoch:52, train acc:0.84, test acc:0.6436
# epoch:53, train acc:0.8466666666666667, test acc:0.6481
# epoch:54, train acc:0.84, test acc:0.6492
# epoch:55, train acc:0.8533333333333334, test acc:0.6561
# epoch:56, train acc:0.8566666666666667, test acc:0.6576
# epoch:57, train acc:0.8533333333333334, test acc:0.6633
# epoch:58, train acc:0.8633333333333333, test acc:0.6669
# epoch:59, train acc:0.8633333333333333, test acc:0.666
# epoch:60, train acc:0.8633333333333333, test acc:0.6684
# epoch:61, train acc:0.8633333333333333, test acc:0.6742
# epoch:62, train acc:0.8733333333333333, test acc:0.6762
# epoch:63, train acc:0.87, test acc:0.6702
# epoch:64, train acc:0.88, test acc:0.68
# epoch:65, train acc:0.89, test acc:0.6818
# epoch:66, train acc:0.8966666666666666, test acc:0.6818
# epoch:67, train acc:0.8966666666666666, test acc:0.6767
# epoch:68, train acc:0.8966666666666666, test acc:0.6852
# epoch:69, train acc:0.9, test acc:0.6747
# epoch:70, train acc:0.9133333333333333, test acc:0.6915
# epoch:71, train acc:0.9166666666666666, test acc:0.6878
# epoch:72, train acc:0.9233333333333333, test acc:0.6896
# epoch:73, train acc:0.92, test acc:0.6933
# epoch:74, train acc:0.9233333333333333, test acc:0.6937
# epoch:75, train acc:0.94, test acc:0.6973
# epoch:76, train acc:0.9366666666666666, test acc:0.7025
# epoch:77, train acc:0.93, test acc:0.6918
# epoch:78, train acc:0.93, test acc:0.7008
# epoch:79, train acc:0.9366666666666666, test acc:0.7007
# epoch:80, train acc:0.9466666666666667, test acc:0.709
# epoch:81, train acc:0.9533333333333334, test acc:0.7094
# epoch:82, train acc:0.94, test acc:0.7063
# epoch:83, train acc:0.9566666666666667, test acc:0.7124
# epoch:84, train acc:0.9466666666666667, test acc:0.7137
# epoch:85, train acc:0.9433333333333334, test acc:0.7112
# epoch:86, train acc:0.9466666666666667, test acc:0.7106
# epoch:87, train acc:0.9566666666666667, test acc:0.7137
# epoch:88, train acc:0.9433333333333334, test acc:0.7095
# epoch:89, train acc:0.95, test acc:0.7123
# epoch:90, train acc:0.96, test acc:0.7164
# epoch:91, train acc:0.96, test acc:0.7132
# epoch:92, train acc:0.9566666666666667, test acc:0.7178
# epoch:93, train acc:0.96, test acc:0.7154
# epoch:94, train acc:0.9566666666666667, test acc:0.7199
# epoch:95, train acc:0.9633333333333334, test acc:0.7227
# epoch:96, train acc:0.9666666666666667, test acc:0.7243
# epoch:97, train acc:0.96, test acc:0.7183
# epoch:98, train acc:0.9733333333333334, test acc:0.7208
# epoch:99, train acc:0.9766666666666667, test acc:0.7252
# epoch:100, train acc:0.98, test acc:0.7225
# epoch:101, train acc:0.9766666666666667, test acc:0.7266
# epoch:102, train acc:0.9833333333333333, test acc:0.7281
# epoch:103, train acc:0.98, test acc:0.728
# epoch:104, train acc:0.9866666666666667, test acc:0.726
# epoch:105, train acc:0.9833333333333333, test acc:0.7276
# epoch:106, train acc:0.9833333333333333, test acc:0.7301
# epoch:107, train acc:0.9833333333333333, test acc:0.7324
# epoch:108, train acc:0.9966666666666667, test acc:0.7268
# epoch:109, train acc:0.9966666666666667, test acc:0.7305
# epoch:110, train acc:0.9933333333333333, test acc:0.732
# epoch:111, train acc:0.9933333333333333, test acc:0.7336
# epoch:112, train acc:0.99, test acc:0.7342
# epoch:113, train acc:0.9966666666666667, test acc:0.7354
# epoch:114, train acc:0.99, test acc:0.7368
# epoch:115, train acc:0.9966666666666667, test acc:0.7381
# epoch:116, train acc:1.0, test acc:0.7322
# epoch:117, train acc:1.0, test acc:0.738
# epoch:118, train acc:1.0, test acc:0.738
# epoch:119, train acc:1.0, test acc:0.7387
# epoch:120, train acc:1.0, test acc:0.7412
# epoch:121, train acc:1.0, test acc:0.7374
# epoch:122, train acc:0.9966666666666667, test acc:0.7405
# epoch:123, train acc:0.9966666666666667, test acc:0.7382
# epoch:124, train acc:1.0, test acc:0.7418
# epoch:125, train acc:1.0, test acc:0.7425
# epoch:126, train acc:1.0, test acc:0.7368
# epoch:127, train acc:1.0, test acc:0.7396
# epoch:128, train acc:1.0, test acc:0.7429
# epoch:129, train acc:1.0, test acc:0.741
# epoch:130, train acc:1.0, test acc:0.7458
# epoch:131, train acc:1.0, test acc:0.743
# epoch:132, train acc:1.0, test acc:0.7455
# epoch:133, train acc:1.0, test acc:0.7421
# epoch:134, train acc:1.0, test acc:0.7465
# epoch:135, train acc:1.0, test acc:0.7428
# epoch:136, train acc:1.0, test acc:0.7441
# epoch:137, train acc:1.0, test acc:0.7447
# epoch:138, train acc:1.0, test acc:0.7457
# epoch:139, train acc:1.0, test acc:0.7458
# epoch:140, train acc:1.0, test acc:0.7456
# epoch:141, train acc:1.0, test acc:0.7459
# epoch:142, train acc:1.0, test acc:0.748
# epoch:143, train acc:1.0, test acc:0.747
# epoch:144, train acc:1.0, test acc:0.7495
# epoch:145, train acc:1.0, test acc:0.7497
# epoch:146, train acc:1.0, test acc:0.7495
# epoch:147, train acc:1.0, test acc:0.7492
# epoch:148, train acc:1.0, test acc:0.7493
# epoch:149, train acc:1.0, test acc:0.7504
# epoch:150, train acc:1.0, test acc:0.748
# epoch:151, train acc:1.0, test acc:0.7519
# epoch:152, train acc:1.0, test acc:0.7501
# epoch:153, train acc:1.0, test acc:0.7488
# epoch:154, train acc:1.0, test acc:0.749
# epoch:155, train acc:1.0, test acc:0.7513
# epoch:156, train acc:1.0, test acc:0.7515
# epoch:157, train acc:1.0, test acc:0.7511
# epoch:158, train acc:1.0, test acc:0.7503
# epoch:159, train acc:1.0, test acc:0.7504
# epoch:160, train acc:1.0, test acc:0.7516
# epoch:161, train acc:1.0, test acc:0.75
# epoch:162, train acc:1.0, test acc:0.7523
# epoch:163, train acc:1.0, test acc:0.7505
# epoch:164, train acc:1.0, test acc:0.7505
# epoch:165, train acc:1.0, test acc:0.7517
# epoch:166, train acc:1.0, test acc:0.7493
# epoch:167, train acc:1.0, test acc:0.7539
# epoch:168, train acc:1.0, test acc:0.7536
# epoch:169, train acc:1.0, test acc:0.7531
# epoch:170, train acc:1.0, test acc:0.7541
# epoch:171, train acc:1.0, test acc:0.7544
# epoch:172, train acc:1.0, test acc:0.752
# epoch:173, train acc:1.0, test acc:0.7557
# epoch:174, train acc:1.0, test acc:0.7553
# epoch:175, train acc:1.0, test acc:0.7564
# epoch:176, train acc:1.0, test acc:0.7558
# epoch:177, train acc:1.0, test acc:0.757
# epoch:178, train acc:1.0, test acc:0.7559
# epoch:179, train acc:1.0, test acc:0.7561
# epoch:180, train acc:1.0, test acc:0.7561
# epoch:181, train acc:1.0, test acc:0.7538
# epoch:182, train acc:1.0, test acc:0.7564
# epoch:183, train acc:1.0, test acc:0.7552
# epoch:184, train acc:1.0, test acc:0.7552
# epoch:185, train acc:1.0, test acc:0.7543
# epoch:186, train acc:1.0, test acc:0.7557
# epoch:187, train acc:1.0, test acc:0.7536
# epoch:188, train acc:1.0, test acc:0.756
# epoch:189, train acc:1.0, test acc:0.7549
# epoch:190, train acc:1.0, test acc:0.7554
# epoch:191, train acc:1.0, test acc:0.7561
# epoch:192, train acc:1.0, test acc:0.756
# epoch:193, train acc:1.0, test acc:0.7549
# epoch:194, train acc:1.0, test acc:0.7556
# epoch:195, train acc:1.0, test acc:0.7574
# epoch:196, train acc:1.0, test acc:0.7573
# epoch:197, train acc:1.0, test acc:0.7572
# epoch:198, train acc:1.0, test acc:0.7578
# epoch:199, train acc:1.0, test acc:0.7571
# epoch:200, train acc:1.0, test acc:0.7573

# %%
# 그래프 그리기==========
markers = {'train': 'o', 'test': 's'}
x = np.arange(max_epochs)
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from common.multi_layer_net import MultiLayerNet
#from common.optimizer import SGD

# https://github.com/WegraLee/deep-learning-from-scratch/blob/master/ch06/overfit_weight_decay.py 참고
from dataset.mnist import load_mnist

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)
# 오버피팅을 재현하기 위해 학습 데이터 수를 줄임
x_train = x_train[:300]
t_train = t_train[:300]

# weight decay（가중치 감쇠） 설정 =======================
#weight_decay_lambda = 0 # weight decay를 사용하지 않을 경우
weight_decay_lambda = 0.1 # weight decay를 사용
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10,
                        weight_decay_lambda=weight_decay_lambda)
optimizer = SGD(lr=0.01) # 학습률이 0.01인 SGD로 매개변수 갱신

max_epochs = 201
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
train_acc_list = []
test_acc_list = []

iter_per_epoch = max(train_size / batch_size, 1)
epoch_cnt = 0

for i in range(1000000000):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]

    grads = network.gradient(x_batch, t_batch)
    optimizer.update(network.params, grads)

    if i % iter_per_epoch == 0:
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list.append(train_acc)
        test_acc_list.append(test_acc)

        print("epoch:" + str(epoch_cnt) + ", train acc:" + str(train_acc) + ", test acc:" + str(test_acc))

        epoch_cnt += 1
        if epoch_cnt >= max_epochs:
            break
# Out:
# epoch:0, train acc:0.15666666666666668, test acc:0.1322
# epoch:1, train acc:0.15666666666666668, test acc:0.1379
# epoch:2, train acc:0.16666666666666666, test acc:0.1491
# epoch:3, train acc:0.19333333333333333, test acc:0.1737
# epoch:4, train acc:0.23666666666666666, test acc:0.1974
# epoch:5, train acc:0.2633333333333333, test acc:0.2081
# epoch:6, train acc:0.2833333333333333, test acc:0.2231
# epoch:7, train acc:0.30333333333333334, test acc:0.243
# epoch:8, train acc:0.33, test acc:0.2572
# epoch:9, train acc:0.3333333333333333, test acc:0.2592
# epoch:10, train acc:0.35, test acc:0.2703
# epoch:11, train acc:0.36333333333333334, test acc:0.2813
# epoch:12, train acc:0.36666666666666664, test acc:0.2839
# epoch:13, train acc:0.37666666666666665, test acc:0.2937
# epoch:14, train acc:0.39666666666666667, test acc:0.3036
# epoch:15, train acc:0.38666666666666666, test acc:0.2994
# epoch:16, train acc:0.4033333333333333, test acc:0.3158
# epoch:17, train acc:0.43, test acc:0.3401
# epoch:18, train acc:0.41, test acc:0.3296
# epoch:19, train acc:0.41, test acc:0.3333
# epoch:20, train acc:0.4266666666666667, test acc:0.3408
# epoch:21, train acc:0.4266666666666667, test acc:0.3474
# epoch:22, train acc:0.42333333333333334, test acc:0.3456
# epoch:23, train acc:0.44333333333333336, test acc:0.3542
# epoch:24, train acc:0.4533333333333333, test acc:0.362
# epoch:25, train acc:0.49333333333333335, test acc:0.3939
# epoch:26, train acc:0.4666666666666667, test acc:0.3854
# epoch:27, train acc:0.46, test acc:0.378
# epoch:28, train acc:0.47, test acc:0.3841
# epoch:29, train acc:0.5066666666666667, test acc:0.3983
# epoch:30, train acc:0.5533333333333333, test acc:0.417
# epoch:31, train acc:0.5733333333333334, test acc:0.4307
# epoch:32, train acc:0.58, test acc:0.4421
# epoch:33, train acc:0.5766666666666667, test acc:0.4293
# epoch:34, train acc:0.5966666666666667, test acc:0.4417
# epoch:35, train acc:0.5966666666666667, test acc:0.444
# epoch:36, train acc:0.6033333333333334, test acc:0.4526
# epoch:37, train acc:0.6133333333333333, test acc:0.4605
# epoch:38, train acc:0.61, test acc:0.4652
# epoch:39, train acc:0.6133333333333333, test acc:0.4673
# epoch:40, train acc:0.6266666666666667, test acc:0.4785
# epoch:41, train acc:0.6366666666666667, test acc:0.4928
# epoch:42, train acc:0.6033333333333334, test acc:0.4828
# epoch:43, train acc:0.6266666666666667, test acc:0.4856
# epoch:44, train acc:0.63, test acc:0.4944
# epoch:45, train acc:0.6566666666666666, test acc:0.5003
# epoch:46, train acc:0.6433333333333333, test acc:0.5051
# epoch:47, train acc:0.6566666666666666, test acc:0.5148
# epoch:48, train acc:0.6733333333333333, test acc:0.5195
# epoch:49, train acc:0.66, test acc:0.5217
# epoch:50, train acc:0.6966666666666667, test acc:0.5343
# epoch:51, train acc:0.7166666666666667, test acc:0.5454
# epoch:52, train acc:0.71, test acc:0.5395
# epoch:53, train acc:0.7166666666666667, test acc:0.5466
# epoch:54, train acc:0.74, test acc:0.5704
# epoch:55, train acc:0.7366666666666667, test acc:0.5815
# epoch:56, train acc:0.7366666666666667, test acc:0.5794
# epoch:57, train acc:0.7366666666666667, test acc:0.588
# epoch:58, train acc:0.73, test acc:0.588
# epoch:59, train acc:0.71, test acc:0.5703
# epoch:60, train acc:0.76, test acc:0.5929
# epoch:61, train acc:0.77, test acc:0.5965
# epoch:62, train acc:0.7366666666666667, test acc:0.5765
# epoch:63, train acc:0.7733333333333333, test acc:0.5989
# epoch:64, train acc:0.7566666666666667, test acc:0.5908
# epoch:65, train acc:0.7733333333333333, test acc:0.5875
# epoch:66, train acc:0.7566666666666667, test acc:0.6008
# epoch:67, train acc:0.7633333333333333, test acc:0.6226
# epoch:68, train acc:0.7766666666666666, test acc:0.6149
# epoch:69, train acc:0.7866666666666666, test acc:0.6293
# epoch:70, train acc:0.7633333333333333, test acc:0.6285
# epoch:71, train acc:0.7866666666666666, test acc:0.6145
# epoch:72, train acc:0.79, test acc:0.6282
# epoch:73, train acc:0.7966666666666666, test acc:0.6234
# epoch:74, train acc:0.79, test acc:0.6284
# epoch:75, train acc:0.8033333333333333, test acc:0.6355
# epoch:76, train acc:0.8033333333333333, test acc:0.6564
# epoch:77, train acc:0.7933333333333333, test acc:0.654
# epoch:78, train acc:0.8066666666666666, test acc:0.6646
# epoch:79, train acc:0.7966666666666666, test acc:0.6504
# epoch:80, train acc:0.7966666666666666, test acc:0.6528
# epoch:81, train acc:0.81, test acc:0.6616
# epoch:82, train acc:0.8266666666666667, test acc:0.6692
# epoch:83, train acc:0.7933333333333333, test acc:0.6585
# epoch:84, train acc:0.8133333333333334, test acc:0.6706
# epoch:85, train acc:0.81, test acc:0.659
# epoch:86, train acc:0.7933333333333333, test acc:0.6564
# epoch:87, train acc:0.8133333333333334, test acc:0.6684
# epoch:88, train acc:0.8066666666666666, test acc:0.6682
# epoch:89, train acc:0.8066666666666666, test acc:0.675
# epoch:90, train acc:0.83, test acc:0.6775
# epoch:91, train acc:0.8133333333333334, test acc:0.6748
# epoch:92, train acc:0.8066666666666666, test acc:0.666
# epoch:93, train acc:0.8233333333333334, test acc:0.6808
# epoch:94, train acc:0.83, test acc:0.675
# epoch:95, train acc:0.82, test acc:0.6775
# epoch:96, train acc:0.82, test acc:0.6924
# epoch:97, train acc:0.8266666666666667, test acc:0.6841
# epoch:98, train acc:0.83, test acc:0.6889
# epoch:99, train acc:0.8233333333333334, test acc:0.687
# epoch:100, train acc:0.83, test acc:0.691
# epoch:101, train acc:0.83, test acc:0.7033
# epoch:102, train acc:0.8433333333333334, test acc:0.7007
# epoch:103, train acc:0.8366666666666667, test acc:0.6888
# epoch:104, train acc:0.84, test acc:0.6799
# epoch:105, train acc:0.8133333333333334, test acc:0.658
# epoch:106, train acc:0.8433333333333334, test acc:0.6882
# epoch:107, train acc:0.8366666666666667, test acc:0.6973
# epoch:108, train acc:0.8333333333333334, test acc:0.6961
# epoch:109, train acc:0.8466666666666667, test acc:0.711
# epoch:110, train acc:0.82, test acc:0.6979
# epoch:111, train acc:0.8433333333333334, test acc:0.699
# epoch:112, train acc:0.8366666666666667, test acc:0.6943
# epoch:113, train acc:0.82, test acc:0.6884
# epoch:114, train acc:0.83, test acc:0.697
# epoch:115, train acc:0.8333333333333334, test acc:0.6918
# epoch:116, train acc:0.83, test acc:0.7019
# epoch:117, train acc:0.8266666666666667, test acc:0.7058
# epoch:118, train acc:0.8433333333333334, test acc:0.6995
# epoch:119, train acc:0.8333333333333334, test acc:0.7129
# epoch:120, train acc:0.8366666666666667, test acc:0.6967
# epoch:121, train acc:0.8433333333333334, test acc:0.6892
# epoch:122, train acc:0.85, test acc:0.7098
# epoch:123, train acc:0.85, test acc:0.7193
# epoch:124, train acc:0.8333333333333334, test acc:0.7059
# epoch:125, train acc:0.86, test acc:0.713
# epoch:126, train acc:0.8566666666666667, test acc:0.7142
# epoch:127, train acc:0.84, test acc:0.6943
# epoch:128, train acc:0.8433333333333334, test acc:0.7145
# epoch:129, train acc:0.8333333333333334, test acc:0.6938
# epoch:130, train acc:0.8466666666666667, test acc:0.7019
# epoch:131, train acc:0.85, test acc:0.7233
# epoch:132, train acc:0.85, test acc:0.7087
# epoch:133, train acc:0.85, test acc:0.7142
# epoch:134, train acc:0.85, test acc:0.7069
# epoch:135, train acc:0.85, test acc:0.6925
# epoch:136, train acc:0.8433333333333334, test acc:0.6986
# epoch:137, train acc:0.86, test acc:0.6973
# epoch:138, train acc:0.85, test acc:0.6856
# epoch:139, train acc:0.8466666666666667, test acc:0.7047
# epoch:140, train acc:0.85, test acc:0.6966
# epoch:141, train acc:0.8633333333333333, test acc:0.7005
# epoch:142, train acc:0.8533333333333334, test acc:0.7032
# epoch:143, train acc:0.8633333333333333, test acc:0.7177
# epoch:144, train acc:0.83, test acc:0.6861
# epoch:145, train acc:0.86, test acc:0.7231
# epoch:146, train acc:0.86, test acc:0.702
# epoch:147, train acc:0.8733333333333333, test acc:0.7218
# epoch:148, train acc:0.8633333333333333, test acc:0.7259
# epoch:149, train acc:0.8466666666666667, test acc:0.6998
# epoch:150, train acc:0.86, test acc:0.7122
# epoch:151, train acc:0.8533333333333334, test acc:0.7101
# epoch:152, train acc:0.8733333333333333, test acc:0.7226
# epoch:153, train acc:0.8666666666666667, test acc:0.7139
# epoch:154, train acc:0.86, test acc:0.7086
# epoch:155, train acc:0.8533333333333334, test acc:0.7162
# epoch:156, train acc:0.8666666666666667, test acc:0.7161
# epoch:157, train acc:0.8733333333333333, test acc:0.7164
# epoch:158, train acc:0.8566666666666667, test acc:0.7049
# epoch:159, train acc:0.86, test acc:0.7017
# epoch:160, train acc:0.86, test acc:0.7145
# epoch:161, train acc:0.8666666666666667, test acc:0.7195
# epoch:162, train acc:0.8533333333333334, test acc:0.7159
# epoch:163, train acc:0.88, test acc:0.7166
# epoch:164, train acc:0.86, test acc:0.7111
# epoch:165, train acc:0.8666666666666667, test acc:0.712
# epoch:166, train acc:0.86, test acc:0.7159
# epoch:167, train acc:0.8566666666666667, test acc:0.7148
# epoch:168, train acc:0.8666666666666667, test acc:0.7133
# epoch:169, train acc:0.8633333333333333, test acc:0.7134
# epoch:170, train acc:0.8666666666666667, test acc:0.7239
# epoch:171, train acc:0.87, test acc:0.7148
# epoch:172, train acc:0.8566666666666667, test acc:0.7026
# epoch:173, train acc:0.8766666666666667, test acc:0.7234
# epoch:174, train acc:0.8666666666666667, test acc:0.723
# epoch:175, train acc:0.88, test acc:0.7153
# epoch:176, train acc:0.8833333333333333, test acc:0.7257
# epoch:177, train acc:0.8766666666666667, test acc:0.7324
# epoch:178, train acc:0.8833333333333333, test acc:0.7291
# epoch:179, train acc:0.87, test acc:0.7203
# epoch:180, train acc:0.88, test acc:0.7281
# epoch:181, train acc:0.8733333333333333, test acc:0.7219
# epoch:182, train acc:0.8733333333333333, test acc:0.7238
# epoch:183, train acc:0.8666666666666667, test acc:0.7232
# epoch:184, train acc:0.86, test acc:0.7081
# epoch:185, train acc:0.86, test acc:0.7109
# epoch:186, train acc:0.8733333333333333, test acc:0.7059
# epoch:187, train acc:0.87, test acc:0.7109
# epoch:188, train acc:0.8633333333333333, test acc:0.7077
# epoch:189, train acc:0.8666666666666667, test acc:0.7159
# epoch:190, train acc:0.86, test acc:0.7089
# epoch:191, train acc:0.8566666666666667, test acc:0.7071
# epoch:192, train acc:0.8733333333333333, test acc:0.715
# epoch:193, train acc:0.8633333333333333, test acc:0.7109
# epoch:194, train acc:0.87, test acc:0.7154
# epoch:195, train acc:0.8733333333333333, test acc:0.7258
# epoch:196, train acc:0.8733333333333333, test acc:0.7185
# epoch:197, train acc:0.87, test acc:0.7179
# epoch:198, train acc:0.87, test acc:0.7192
# epoch:199, train acc:0.8633333333333333, test acc:0.7127
# epoch:200, train acc:0.8533333333333334, test acc:0.7158

# %%
# 그래프 그리기==========
markers = {'train': 'o', 'test': 's'}
x = np.arange(max_epochs)
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()

# %%
class Dropout:
    def __init__(self, dropout_ratio=0.5):
        self.dropout_ratio = dropout_ratio
        self.mask = None

    def forward(self, x, train_flg=True):
        if train_flg:
            self.mask = np.random.rand(*x.shape) > self.dropout_ratio
            return x * self.mask
        else:
            return x * (1.0 - self.dropout_ratio)

    def backward(self, dout):
        return dout * self.mask

# %%
# coding: utf-8
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net_extend import MultiLayerNetExtend
from common.trainer import Trainer

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 오버피팅을 재현하기 위해 학습 데이터 수를 줄임
x_train = x_train[:300]
t_train = t_train[:300]

# 드롭아웃 사용 유무와 비울 설정 ========================
use_dropout = True  # 드롭아웃을 쓰지 않을 때는 False
dropout_ratio = 0.2
# ====================================================

network = MultiLayerNetExtend(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100],
                              output_size=10, use_dropout=use_dropout, dropout_ration=dropout_ratio)
trainer = Trainer(network, x_train, t_train, x_test, t_test,
                  epochs=301, mini_batch_size=100,
                  optimizer='sgd', optimizer_param={'lr': 0.01}, verbose=False)
trainer.train()

train_acc_list, test_acc_list = trainer.train_acc_list, trainer.test_acc_list

# 그래프 그리기==========
markers = {'train': 'o', 'test': 's'}
x = np.arange(len(train_acc_list))
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()

# %%
# https://github.com/WegraLee/deep-learning-from-scratch/blob/master/ch06/hyperparameter_optimization.py 참고
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net import MultiLayerNet
from common.util import shuffle_dataset
from common.trainer import Trainer

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 결과를 빠르게 얻기 위해 훈련 데이터를 줄임
x_train = x_train[:500]
t_train = t_train[:500]

# 20%를 검증 데이터로 분할
validation_rate = 0.20
validation_num = int(x_train.shape[0] * validation_rate)
x_train, t_train = shuffle_dataset(x_train, t_train)
x_val = x_train[:validation_num]
t_val = t_train[:validation_num]
x_train = x_train[validation_num:]
t_train = t_train[validation_num:]


def __train(lr, weight_decay, epocs=50):
    network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100],
                            output_size=10, weight_decay_lambda=weight_decay)
    trainer = Trainer(network, x_train, t_train, x_val, t_val,
                      epochs=epocs, mini_batch_size=100,
                      optimizer='sgd', optimizer_param={'lr': lr}, verbose=False)
    trainer.train()

    return trainer.test_acc_list, trainer.train_acc_list


# 하이퍼파라미터 무작위 탐색======================================
optimization_trial = 100
results_val = {}
results_train = {}
for _ in range(optimization_trial):
    # 탐색한 하이퍼파라미터의 범위 지정===============
    weight_decay = 10 ** np.random.uniform(-8, -4)
    lr = 10 ** np.random.uniform(-6, -2)
    # ================================================

    val_acc_list, train_acc_list = __train(lr, weight_decay)
    print("val acc:" + str(val_acc_list[-1]) + " | lr:" + str(lr) + ", weight decay:" + str(weight_decay))
    key = "lr:" + str(lr) + ", weight decay:" + str(weight_decay)
    results_val[key] = val_acc_list
    results_train[key] = train_acc_list

# 그래프 그리기========================================================
print("=========== Hyper-Parameter Optimization Result ===========")
graph_draw_num = 20
col_num = 5
row_num = int(np.ceil(graph_draw_num / col_num))
i = 0

for key, val_acc_list in sorted(results_val.items(), key=lambda x:x[1][-1], reverse=True):
    print("Best-" + str(i+1) + "(val acc:" + str(val_acc_list[-1]) + ") | " + key)

    plt.subplot(row_num, col_num, i+1)
    plt.title("Best-" + str(i+1))
    plt.ylim(0.0, 1.0)
    if i % 5: plt.yticks([])
    plt.xticks([])
    x = np.arange(len(val_acc_list))
    plt.plot(x, val_acc_list)
    plt.plot(x, results_train[key], "--")
    i += 1

    if i >= graph_draw_num:
        break

plt.show()
# Out:
# val acc:0.37 | lr:0.001917315345457555, weight decay:8.987488477000866e-05
# val acc:0.17 | lr:1.880749429139423e-05, weight decay:6.577538916228703e-05
# val acc:0.12 | lr:1.6934478892794892e-06, weight decay:5.65374761062585e-05
# val acc:0.09 | lr:3.502392664784176e-05, weight decay:7.626457960523106e-08
# val acc:0.77 | lr:0.007288811513891085, weight decay:1.0822745583046238e-06
# val acc:0.13 | lr:1.0716802248693005e-06, weight decay:7.35165007012487e-05
# val acc:0.1 | lr:1.8680426163063586e-06, weight decay:1.7276736852211288e-08
# val acc:0.11 | lr:0.00013442281436437848, weight decay:2.8361447289082612e-05
# val acc:0.14 | lr:6.02078909734244e-05, weight decay:3.797083253951272e-07
# val acc:0.14 | lr:0.00014292888433505282, weight decay:1.0166750761460962e-06
# val acc:0.43 | lr:0.0035806586628841794, weight decay:8.111742846502458e-06
# val acc:0.06 | lr:4.350829969656659e-05, weight decay:1.1959758337949087e-05
# val acc:0.06 | lr:2.784563611188087e-06, weight decay:1.6675546765455362e-05
# val acc:0.15 | lr:0.00024359137694272807, weight decay:3.683585321698939e-08
# val acc:0.07 | lr:4.6594630726446265e-05, weight decay:6.167722332597513e-08
# val acc:0.15 | lr:0.00011064567796683596, weight decay:2.4775961938381343e-06
# val acc:0.05 | lr:2.0800941827414903e-05, weight decay:2.0484494748365347e-08
# val acc:0.24 | lr:0.00038935821400332024, weight decay:2.773971209914257e-07
# val acc:0.03 | lr:4.733943920255423e-05, weight decay:1.95974257164208e-07
# val acc:0.8 | lr:0.007990046161621264, weight decay:6.253127258643263e-08
# val acc:0.09 | lr:3.8745315903348215e-06, weight decay:2.1542066210997833e-06
# val acc:0.15 | lr:1.1471268943232777e-05, weight decay:2.6073846499224814e-08
# val acc:0.07 | lr:3.079770831485565e-05, weight decay:2.0732834035816104e-08
# val acc:0.07 | lr:2.3980349782502215e-05, weight decay:3.922699528748901e-08
# val acc:0.1 | lr:0.00014494246444058794, weight decay:1.0502808000025783e-05
# val acc:0.19 | lr:0.001297270851335084, weight decay:7.446986210606184e-07
# val acc:0.16 | lr:9.89847822767899e-06, weight decay:6.069087800243593e-08
# val acc:0.04 | lr:0.0002823898867222537, weight decay:3.545120126301078e-08
# val acc:0.03 | lr:1.8161239383322439e-06, weight decay:4.429532914115032e-07
# val acc:0.13 | lr:0.00036592299983969565, weight decay:7.73777780560926e-07
# val acc:0.7 | lr:0.006560667543076741, weight decay:1.2466097207571266e-07
# val acc:0.15 | lr:2.1068105828310717e-05, weight decay:1.7356920188515218e-06
# val acc:0.05 | lr:1.1090138466382477e-06, weight decay:2.1963530529780697e-05
# val acc:0.14 | lr:0.0003359357987184174, weight decay:1.160031979993245e-05
# val acc:0.08 | lr:5.263922342613707e-06, weight decay:2.255895211990062e-05
# val acc:0.24 | lr:0.0009717909090713821, weight decay:2.0596134014909364e-06
# val acc:0.1 | lr:0.0002892928799572451, weight decay:3.968748897185054e-05
# val acc:0.05 | lr:1.6580455741978192e-06, weight decay:5.260770588152855e-08
# val acc:0.05 | lr:0.00066554546419011, weight decay:1.620349711665607e-08
# val acc:0.21 | lr:0.00010375317794366677, weight decay:5.843041769213894e-05
# val acc:0.11 | lr:7.703561475600069e-06, weight decay:5.945401573727599e-07
# val acc:0.09 | lr:6.489339106470519e-06, weight decay:2.4325795177349303e-08
# val acc:0.06 | lr:1.8224570290754633e-05, weight decay:1.3150350522018358e-07
# val acc:0.07 | lr:1.485440434213993e-06, weight decay:9.406152585404636e-05
# val acc:0.1 | lr:1.7405461374539701e-06, weight decay:1.5053630971830653e-05
# val acc:0.18 | lr:0.0005171631477184184, weight decay:4.891872053704136e-08
# val acc:0.26 | lr:0.0009915203140700554, weight decay:1.1191838470912573e-08
# val acc:0.14 | lr:3.7025535510005676e-06, weight decay:4.858260748708534e-05
# val acc:0.07 | lr:3.3260543767404134e-05, weight decay:3.803431624957284e-05
# val acc:0.1 | lr:9.734969702663074e-06, weight decay:3.6902153789785426e-08
# val acc:0.16 | lr:0.0003027754671309641, weight decay:1.6855296317180503e-07
# val acc:0.15 | lr:0.00011370459405237325, weight decay:6.708741106926752e-05
# val acc:0.56 | lr:0.004169782303626382, weight decay:6.673786265303984e-05
# val acc:0.7 | lr:0.0068565281340167775, weight decay:1.5145661605868827e-08
# val acc:0.13 | lr:0.0001515059415422714, weight decay:2.7668530010837396e-06
# val acc:0.1 | lr:1.2738633733380754e-05, weight decay:4.03288044591799e-06
# val acc:0.36 | lr:0.0014991010933387483, weight decay:3.245415415677624e-07
# val acc:0.14 | lr:2.4661316353453575e-05, weight decay:9.997559510840722e-05
# val acc:0.74 | lr:0.00582916153445489, weight decay:4.627924756212464e-07
# val acc:0.06 | lr:2.565613579748377e-06, weight decay:6.501610509705226e-06
# val acc:0.08 | lr:8.853741526699498e-05, weight decay:7.513484404132565e-07
# val acc:0.11 | lr:1.7371070118071305e-06, weight decay:7.888685369504073e-08
# val acc:0.73 | lr:0.005205193318707568, weight decay:7.318049862191412e-08
# val acc:0.07 | lr:1.077337251929379e-06, weight decay:1.5740363621693943e-07
# val acc:0.1 | lr:4.870388018352569e-06, weight decay:4.414810432241762e-07
# val acc:0.12 | lr:0.0004358905634440375, weight decay:1.8483484074509226e-08
# val acc:0.1 | lr:1.965346806647676e-05, weight decay:9.48588790892957e-06
# val acc:0.1 | lr:4.562978667894579e-06, weight decay:5.2785026560235296e-06
# val acc:0.08 | lr:0.00026431251451136255, weight decay:1.7844129964625918e-05
# val acc:0.45 | lr:0.002851960459434906, weight decay:5.074713070992194e-07
# val acc:0.02 | lr:0.00012743789551947457, weight decay:1.2174573576740457e-08
# val acc:0.15 | lr:2.1793478579722123e-05, weight decay:1.3534639455364656e-05
# val acc:0.69 | lr:0.0043473042753847824, weight decay:5.209391067872826e-08
# val acc:0.09 | lr:0.0009550231334602451, weight decay:5.783592034088964e-06
# val acc:0.14 | lr:0.00039201591265410453, weight decay:1.622452913746178e-05
# val acc:0.08 | lr:2.5089250613105653e-05, weight decay:5.011398138791178e-07
# val acc:0.1 | lr:7.512812042154728e-05, weight decay:7.521389299079583e-07
# val acc:0.17 | lr:0.0011778570037632656, weight decay:1.2260641233341363e-07
# val acc:0.03 | lr:1.6069968174319888e-05, weight decay:1.2952711730347408e-08
# val acc:0.11 | lr:4.09584541231017e-06, weight decay:5.7567929429173426e-08
# val acc:0.07 | lr:0.0001627938302238805, weight decay:5.381517896847594e-07
# val acc:0.42 | lr:0.0024760318978257513, weight decay:1.1326815666391281e-05
# val acc:0.06 | lr:2.7209835060568525e-05, weight decay:3.4496936936304445e-07
# val acc:0.06 | lr:0.00015455389007291038, weight decay:4.386267497049091e-05
# val acc:0.26 | lr:0.0008037455083760367, weight decay:5.899673948872318e-08
# val acc:0.1 | lr:2.837018090306961e-06, weight decay:2.47686638971784e-05
# val acc:0.12 | lr:1.0821952150204822e-06, weight decay:1.3540027897592525e-06
# val acc:0.15 | lr:4.086449900329487e-06, weight decay:3.306327900778901e-07
# val acc:0.1 | lr:2.9276136057234117e-06, weight decay:1.9374756572531305e-08
# val acc:0.08 | lr:2.5031335671612743e-06, weight decay:4.8205258589101095e-08
# val acc:0.16 | lr:0.00014107152827001754, weight decay:8.575889228240448e-07
# val acc:0.1 | lr:3.5226293879138168e-06, weight decay:4.700785509545598e-06
# val acc:0.16 | lr:4.390241913365743e-06, weight decay:8.72122082894593e-05
# val acc:0.22 | lr:0.0013053293675960348, weight decay:7.649655248581386e-07
# val acc:0.15 | lr:4.487230653070038e-05, weight decay:1.7469650387701324e-07
# val acc:0.12 | lr:0.0001595560762685008, weight decay:1.5592695235376376e-07
# val acc:0.54 | lr:0.00425536575850038, weight decay:5.3154818729351805e-08
# val acc:0.11 | lr:0.0002462463905039698, weight decay:1.2111295625165516e-06
# val acc:0.13 | lr:1.9435834019786e-06, weight decay:1.7723687564906156e-07
# val acc:0.18 | lr:0.0006183380778957661, weight decay:2.3518637935428856e-06
# =========== Hyper-Parameter Optimization Result ===========
# Best-1(val acc:0.8) | lr:0.007990046161621264, weight decay:6.253127258643263e-08
# Best-2(val acc:0.77) | lr:0.007288811513891085, weight decay:1.0822745583046238e-06
# Best-3(val acc:0.74) | lr:0.00582916153445489, weight decay:4.627924756212464e-07
# Best-4(val acc:0.73) | lr:0.005205193318707568, weight decay:7.318049862191412e-08
# Best-5(val acc:0.7) | lr:0.006560667543076741, weight decay:1.2466097207571266e-07
# Best-6(val acc:0.7) | lr:0.0068565281340167775, weight decay:1.5145661605868827e-08
# Best-7(val acc:0.69) | lr:0.0043473042753847824, weight decay:5.209391067872826e-08
# Best-8(val acc:0.56) | lr:0.004169782303626382, weight decay:6.673786265303984e-05
# Best-9(val acc:0.54) | lr:0.00425536575850038, weight decay:5.3154818729351805e-08
# Best-10(val acc:0.45) | lr:0.002851960459434906, weight decay:5.074713070992194e-07
# Best-11(val acc:0.43) | lr:0.0035806586628841794, weight decay:8.111742846502458e-06
# Best-12(val acc:0.42) | lr:0.0024760318978257513, weight decay:1.1326815666391281e-05
# Best-13(val acc:0.37) | lr:0.001917315345457555, weight decay:8.987488477000866e-05
# Best-14(val acc:0.36) | lr:0.0014991010933387483, weight decay:3.245415415677624e-07
# Best-15(val acc:0.26) | lr:0.0009915203140700554, weight decay:1.1191838470912573e-08
# Best-16(val acc:0.26) | lr:0.0008037455083760367, weight decay:5.899673948872318e-08
# Best-17(val acc:0.24) | lr:0.00038935821400332024, weight decay:2.773971209914257e-07
# Best-18(val acc:0.24) | lr:0.0009717909090713821, weight decay:2.0596134014909364e-06
# Best-19(val acc:0.22) | lr:0.0013053293675960348, weight decay:7.649655248581386e-07
# Best-20(val acc:0.21) | lr:0.00010375317794366677, weight decay:5.843041769213894e-05
