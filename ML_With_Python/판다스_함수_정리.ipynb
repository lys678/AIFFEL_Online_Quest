# %% [markdown]
# <a href="https://colab.research.google.com/github/comandi1969/AIFFEL_Online_Quest/blob/main/ML_With_Python/%ED%8C%90%EB%8B%A4%EC%8A%A4_%ED%95%A8%EC%88%98_%EC%A0%95%EB%A6%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# 예제 데이터프레임 생성
data = {'이름': ['Alice', 'Bob', 'Charlie', 'Dave', 'Eve'],
        '나이': [25, 30, 35, 40, 45],
        '성별': ['여성', '남성', '남성', '남성', '여성']}
df = pd.DataFrame(data)
#df
#print(df)

df.head(3) #데이터프레임의 처음 몇 개의 행을 반환합니다.

df.tail(2) #데이터프레임의 마지막 몇 개의 행을 반환합니다.

df.info() #데이터프레임의 요약 정보를 출력합니다.

df.describe() # 데이터프레임의 주요 통계량을 요약하여 출력합니다.

df.shape # 데이터프레임의 행과 열의 개수를 반환합니다.

df.columns # 데이터프레임의 열 이름을 반환합니다.

df.index # 데이터프레임의 인덱스 값을 반환합니다.

df['성별'].unique() # 열에서 중복을 제외한 고유한 값들을 반환합니다.

df['성별'].value_counts() # 열의 고유한 값들의 개수를 계산하여 반환합니다.

df.sort_values(by='나이', ascending=True) # 지정된 열을 기준으로 데이터프레임을 정렬합니다.

# '성별'을 기준으로 그룹화하고 '나이'의 합계와 평균을 계산
grouped = df.groupby('성별') # groupby(): 지정된 열을 기준으로 데이터를 그룹화합니다.
agg_result = grouped['나이'].agg(['sum', 'mean'])
print(agg_result)

# 결측치가 있는 새로운 레코드 추가
new_record = {'이름': 'James', '성별': '남성'}
df = df.append(new_record, ignore_index=True)
print(df)

df = df.fillna(0) # 결측값을 지정된 값으로 채웁니다.
print(df)

df = df.dropna() # 결측값이 포함된 행을 제거합니다.
print(df)

df1 = pd.DataFrame({'Name': ['Alice', 'Mary'], 'Age': [20, 25]})
df2 = pd.DataFrame({'Name': ['Alice'], 'Sex': ['Male']})
df = pd.merge(df1, df2, on='Name') # merge() 함수는 두 개 이상의 DataFrame을 공통 열을 기준으로 병합하는 함수
print(df)

df1 = pd.DataFrame({'Name': ['John', 'Mary'], 'Age': [20, 25]})
df2 = pd.DataFrame({'Name': ['Alice'], 'Age': [30]})
df = pd.concat([df1, df2]) # concat() 함수는 두 개 이상의 DataFrame을 하나로 합치는 함수
print(df)

df = pd.DataFrame({'Customer ID': [1, 2, 3], 'Product Category': ['Electronics', 'Clothing', 'Food'], 'Quantity': [1, 2, 3]})
new_record = pd.DataFrame({'Customer ID': [1], 'Product Category': ['Clothing'], 'Quantity': [3]})
df = pd.concat([df, new_record], ignore_index=True)
df_pivot = df.pivot_table(index='Customer ID', columns='Product Category', values='Quantity', aggfunc='sum') # 고객 ID와 제품 카테고리별로 구매량을 요약
print(df_pivot)

data = {'이름': ['Alice', 'Bob', 'Charlie', 'Dave', 'Alice'],
        '나이': [25, 30, 35, 40, 25],
        '성별': ['여성', '남성', '남성', '남성', '여성']}
df = pd.DataFrame(data)
duplicates = df.duplicated() # 중복된 행을 식별합니다.
print(duplicates)

data = {'이름': ['Alice', 'Bob', 'Charlie', 'Dave', 'Alice'],
        '나이': [25, 30, 35, 40, 25],
        '성별': ['여성', '남성', '남성', '남성', '여성']}
df = pd.DataFrame(data)
print(df)
duplicates_droped = df.drop_duplicates() # 중복된 행을 제거합니다.
print(duplicates_droped)

df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6], 'C': [7, 8, 9]})
print(df)
df_corr = df.corr() # DataFrame의 열 간의 상관관계를 계산
print(df_corr)

df = pd.DataFrame({'x': [1, 2, 3], 'y': [4, 5, 6]})
#df_corr = df.corr() # DataFrame의 열 간의 상관관계를 계산
#print(df_corr)
df.plot(x='x', y='y', kind='line', title='Line Chart', xlabel='x', ylabel='y') # 데이터프레임의 시각화를 수행합니다.

df = pd.DataFrame({'x': [1, 2, 3], 'y': [4, 5, 6]})
df.to_csv('output.csv', index=False, header=True, sep=',') # 데이터프레임을 CSV 파일로 저장

df = pd.DataFrame({'x': [1, 2, 3], 'y': [4, 5, 6]})
df.to_excel('output.xlsx', sheet_name='Sheet1', index=False, header=True) # 데이터프레임을 Excel 파일로 저장

df = pd.DataFrame({'x': [1, 2, 3], 'y': [4, 5, 6]})
print(df.mean()) # 열의 평균을 계산합니다.
print(df.sum()) # 열의 합계를 계산합니다.
print(df.max()) # 열의 최댓값을 찾습니다.
print(df.min()) # 열의 최솟값을 찾습니다.
print(df.std()) # 열의 표준편차를 계산합니다.

data = {'이름': ['Alice', 'Bob', 'Charlie', 'Dave', 'Alice'],
        '나이': [25, 30, 35, 40, 25],
        '성별': ['여성', '남성', '남성', '남성', '여성']}
df = pd.DataFrame(data)
print(df['나이'].mean()) # 열의 평균을 계산합니다.

df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6], 'C': [7, 8, 9]})
print(df)
print()
df = df.drop(labels=[0], axis=0) # 첫 번째 행을 삭제합니다.
print(df)

df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6], 'C': [7, 8, 9]})
print(df)
print()
df = df.drop(labels=[1], axis=0) # 두 번째 행을 삭제합니다.
print(df)

df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6], 'C': [7, 8, 9]})
print(df)
print()
df = df.drop(labels=['A'], axis=1) # 첫 번째 열을 삭제합니다.
print(df)

df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6], 'C': [7, 8, 9]})
print(df)
print()
df = df.drop(labels=['B'], axis=1) # 두 번째 열을 삭제합니다.
print(df)

df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
# 함수를 적용하여 새로운 열을 생성합니다.
df['C'] = df.apply(lambda x: x['A'] + x['B'], axis=1)
print(df)
# Out:
#    A  B  C
# 0  1  4  5
# 1  2  5  7
# 2  3  6  9
