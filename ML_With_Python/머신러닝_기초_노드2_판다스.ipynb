# %% [markdown]
# <a href="https://colab.research.google.com/github/comandi1969/AIFFEL_Online_Quest/blob/main/ML_With_Python/%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D_%EA%B8%B0%EC%B4%88_%EB%85%B8%EB%93%9C2_%ED%8C%90%EB%8B%A4%EC%8A%A4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
menu_list = ['후라이드', '양념치킨', '양반후반']
#menu = pd.Series(menu_list)
menu = pd.Series(menu_list, name='메뉴') # index 이름을 '메뉴'로 지정
menu
type(menu)
# Out:
# pandas.core.series.Series

# %%
p_list = ['12000', '13000', '13000']
price = pd.Series(p_list, name = '가격')
price
type(price)
# Out:
# pandas.core.series.Series

# %%
df = pd.DataFrame({'메뉴': menu, '가격': price})
display(df)
# Out:
#      메뉴     가격
# 0  후라이드  12000
# 1  양념치킨  13000
# 2  양반후반  13000

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
data = {'메뉴': ['후라이드', '양념치킨', '양반후반'],
        '가격': [12000, 13000, 13000],
        '호수': ['10호', '10호', '9호']}
df = pd.DataFrame(data)
df
# Out:
#      메뉴     가격   호수
# 0  후라이드  12000  10호
# 1  양념치킨  13000  10호
# 2  양반후반  13000   9호

# %%
import pandas as pd # 판다스 모듈 임포트 후 별칭 지정 pd
data = { # data는 2차원 배열 또는 딕셔너리로 입력
    "메뉴":['후라이드', '양념치킨', '간장치킨', '마늘치킨', '파닭', '닭강정', '양반후반'],
    "가격":[12000, 13000, 14000, 14000, 14000, 15000, 13000],
    "호수":['10호', '10호', '9호', '9호', '11호', '12호', '10호'],
    "칼로리":[1000, 1400, 1600, 1800, 1300, 1500, 1300],
}
data = pd.DataFrame(data) # pd.DataFrame(data, index=None, columns=None), 데이터프레임 생성
data.to_csv('modudak.csv', index=False) # 데이터프레임을 CSV 파일로 저장

# %%
pd.read_csv('modudak.csv')
# Out:
#      메뉴     가격   호수   칼로리
# 0  후라이드  12000  10호  1000
# 1  양념치킨  13000  10호  1400
# 2  간장치킨  14000   9호  1600
# 3  마늘치킨  14000   9호  1800
# 4    파닭  14000  11호  1300
# 5   닭강정  15000  12호  1500
# 6  양반후반  13000  10호  1300

# %%
df = pd.read_csv('modudak.csv') # CSV 파일을 읽어 데이터프레임 자료 구조로 할당
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.tail(3)
# Out:
#      메뉴     가격   호수   칼로리
# 4    파닭  14000  11호  1300
# 5   닭강정  15000  12호  1500
# 6  양반후반  13000  10호  1300

# %%
df.head(2)
# Out:
#      메뉴     가격   호수   칼로리
# 0  후라이드  12000  10호  1000
# 1  양념치킨  13000  10호  1400

# %%
df.to_csv('test.csv', index=False) # 저장 시 index 값을 제외

# %%
pd.read_csv('test.csv')
# Out:
#      메뉴     가격   호수   칼로리
# 0  후라이드  12000  10호  1000
# 1  양념치킨  13000  10호  1400
# 2  간장치킨  14000   9호  1600
# 3  마늘치킨  14000   9호  1800
# 4    파닭  14000  11호  1300
# 5   닭강정  15000  12호  1500
# 6  양반후반  13000  10호  1300

# %%
# 열 선택
type(df[['메뉴']]) # 데이터프레임
type(df['메뉴']) # 시리즈
type(df.메뉴) # 시리즈
# Out:
# pandas.core.series.Series

# %%
print(df)
df[['메뉴', '가격']]
#df['메뉴', '가격'] # 2개 이상의 시리즈는 데이터프레임 형식으로 출력해야 함
df.loc[0] # 시리즈
type(df.loc[0])
df.loc[[0]] # 데이터프레임
type(df.loc[[0]])
# Out:
#      메뉴     가격   호수   칼로리
# 0  후라이드  12000  10호  1000
# 1  양념치킨  13000  10호  1400
# 2  간장치킨  14000   9호  1600
# 3  마늘치킨  14000   9호  1800
# 4    파닭  14000  11호  1300
# 5   닭강정  15000  12호  1500
# 6  양반후반  13000  10호  1300
# pandas.core.frame.DataFrame

# %%
type(df[['메뉴', '가격']])
# Out:
# pandas.core.frame.DataFrame

# %%
df['가격'] >= 14000
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# 5     True
# 6    False
# Name: 가격, dtype: bool

# %%
# 행 출력
cond = df['가격'] >= 14000
df[cond]
# Out:
#      메뉴     가격   호수   칼로리
# 2  간장치킨  14000   9호  1600
# 3  마늘치킨  14000   9호  1800
# 4    파닭  14000  11호  1300
# 5   닭강정  15000  12호  1500

# %%
cond1 = df['가격'] >= 14000
cond2 = df['호수'] == '9호'
df[cond1 & cond2] # AND 조건으로 데이터프레임에서 행을 선택
# Out:
#      메뉴     가격  호수   칼로리
# 2  간장치킨  14000  9호  1600
# 3  마늘치킨  14000  9호  1800

# %%
# 행 출력
cond1 = df['가격'] >= 14000
cond2 = df['호수'] == '9호'

df[cond1 | cond2] # OR 조건으로 데이터프레임에서 행을 선택
# Out:
#      메뉴     가격   호수   칼로리
# 2  간장치킨  14000   9호  1600
# 3  마늘치킨  14000   9호  1800
# 4    파닭  14000  11호  1300
# 5   닭강정  15000  12호  1500

# %%
df = pd.read_csv('modudak.csv')
#display(df)
cond = df['호수'].isin(['9호', '10호'])
#display(cond)
df[cond]
#df[df['호수'].isin(['9호', '10호'])]
#df[['호수']] # 데이터프레임 출력
#df['호수'] # 시리즈 출력
# Out:
#      메뉴     가격   호수   칼로리
# 0  후라이드  12000  10호  1000
# 1  양념치킨  13000  10호  1400
# 2  간장치킨  14000   9호  1600
# 3  마늘치킨  14000   9호  1800
# 6  양반후반  13000  10호  1300

# %%
# 데이터프레임의 인덱싱과 슬라이싱
df = pd.read_csv('modudak.csv')
display(df)
df['index'] = ['a', 'b', 'c', 'd', 'e', 'f', 'g'] # "index"라는 이름의 알파벳 컬럼을 추가
display(df)
df = df.set_index(keys=['index']) # 인덱스를 알파벳 컬럼으로 변경
display(df)
# Out:
#      메뉴     가격   호수   칼로리
# 0  후라이드  12000  10호  1000
# 1  양념치킨  13000  10호  1400
# 2  간장치킨  14000   9호  1600
# 3  마늘치킨  14000   9호  1800
# 4    파닭  14000  11호  1300
# 5   닭강정  15000  12호  1500
# 6  양반후반  13000  10호  1300
#      메뉴     가격   호수   칼로리 index
# 0  후라이드  12000  10호  1000     a
# 1  양념치킨  13000  10호  1400     b
# 2  간장치킨  14000   9호  1600     c
# 3  마늘치킨  14000   9호  1800     d
# 4    파닭  14000  11호  1300     e
# 5   닭강정  15000  12호  1500     f
# 6  양반후반  13000  10호  1300     g
#          메뉴     가격   호수   칼로리
# index
# a      후라이드  12000  10호  1000
# b      양념치킨  13000  10호  1400
# c      간장치킨  14000   9호  1600
# d      마늘치킨  14000   9호  1800
# e        파닭  14000  11호  1300
# f       닭강정  15000  12호  1500
# g      양반후반  13000  10호  1300

# %%
df.loc['a'] # 인덱스 명(범위), 컬럼 명(범위), 시리즈 리턴
df.loc[['a']] # 인덱스 명(범위), 컬럼 명(범위), 데이터프레임 리턴
# Out:
#          메뉴     가격   호수   칼로리
# index
# a      후라이드  12000  10호  1000

# %%
# df.loc[인덱스명] => 해당 인덱스 행의 모든 컬럼을 출력
# df.loc[인덱스명, 컬럼명] => 해당 인덱스 행의 해당 컬럼을 출력
display(df.loc[:, '가격']) # 인덱스 전체 행 중 가격 컬럼 리턴
cond = df['가격'] >= 14000
display(df[cond])
display(df.loc[cond, '메뉴']) # 가격이 14000 이상인 메뉴 컬럼만 출력, cond에서 행을 제한
# Out:
# index
# a    12000
# b    13000
# c    14000
# d    14000
# e    14000
# f    15000
# g    13000
# Name: 가격, dtype: int64
#          메뉴     가격   호수   칼로리
# index
# c      간장치킨  14000   9호  1600
# d      마늘치킨  14000   9호  1800
# e        파닭  14000  11호  1300
# f       닭강정  15000  12호  1500
# index
# c    간장치킨
# d    마늘치킨
# e      파닭
# f     닭강정
# Name: 메뉴, dtype: object

# %%
df.loc[:, '가격'] # 전체 행의 가격 컬럼을 출력

df.loc['b', '가격'] # 인덱스 b(양념치킨) 행의 가격 컬럼을 출력
# Out:
# 13000

# %%
df
# Out:
#          메뉴     가격   호수   칼로리
# index
# a      후라이드  12000  10호  1000
# b      양념치킨  13000  10호  1400
# c      간장치킨  14000   9호  1600
# d      마늘치킨  14000   9호  1800
# e        파닭  14000  11호  1300
# f       닭강정  15000  12호  1500
# g      양반후반  13000  10호  1300

# %%
df.loc['c', ['메뉴', '가격']]
df.loc['c', ['메뉴', '호수']]
df.loc['c', ['메뉴', '가격', '호수']]
df.loc['c', ['메뉴', '가격', '호수', '칼로리']]

df.loc['c', '메뉴':'가격']
df.loc['c', '메뉴':'호수']
df.loc['c', '메뉴':'칼로리']
# Out:
# 메뉴     간장치킨
# 가격    14000
# Name: c, dtype: object

# %%
df.loc['c', ['메뉴', '칼로리']]
# Out:
# 메뉴     간장치킨
# 칼로리    1600
# Name: c, dtype: object

# %%
df.loc['b':'d', '메뉴':'가격']
# Out:
#          메뉴     가격
# index
# b      양념치킨  13000
# c      간장치킨  14000
# d      마늘치킨  14000

# %%
df.loc[:'d', '메뉴':'가격']
# Out:
#          메뉴     가격
# index
# a      후라이드  12000
# b      양념치킨  13000
# c      간장치킨  14000
# d      마늘치킨  14000

# %%
df
# Out:
#          메뉴     가격   호수   칼로리
# index
# a      후라이드  12000  10호  1000
# b      양념치킨  13000  10호  1400
# c      간장치킨  14000   9호  1600
# d      마늘치킨  14000   9호  1800
# e        파닭  14000  11호  1300
# f       닭강정  15000  12호  1500
# g      양반후반  13000  10호  1300

# %%
df.loc['b':, '메뉴':'가격']
df.loc['b':, :]
# Out:
#          메뉴     가격   호수   칼로리
# index
# b      양념치킨  13000  10호  1400
# c      간장치킨  14000   9호  1600
# d      마늘치킨  14000   9호  1800
# e        파닭  14000  11호  1300
# f       닭강정  15000  12호  1500
# g      양반후반  13000  10호  1300

# %%
df.loc[:, '메뉴':'가격']
# Out:
#          메뉴     가격
# index
# a      후라이드  12000
# b      양념치킨  13000
# c      간장치킨  14000
# d      마늘치킨  14000
# e        파닭  14000
# f       닭강정  15000
# g      양반후반  13000

# %%
df.loc[['b', 'd'], '메뉴':'가격']
# Out:
#          메뉴     가격
# index
# b      양념치킨  13000
# d      마늘치킨  14000

# %%
df
df.loc[:, :] # == df
# Out:
#          메뉴     가격   호수   칼로리
# index
# a      후라이드  12000  10호  1000
# b      양념치킨  13000  10호  1400
# c      간장치킨  14000   9호  1600
# d      마늘치킨  14000   9호  1800
# e        파닭  14000  11호  1300
# f       닭강정  15000  12호  1500
# g      양반후반  13000  10호  1300

# %%
# df.loc[인덱스명] => 해당 인덱스 행의 모든 컬럼을 출력
# df.loc[인덱스명, 컬럼명] => 해당 인덱스 행의 해당 컬럼을 출력
# df.iloc[인덱스 번호(범위)]
# df.iloc[인덱스 번호(범위), 컬럼 번호(범위)]
df.iloc[0] #  == df.iloc[0, :]
df.iloc[0:3] # == df.iloc[0:3, :]
df.iloc[0, 0]
df.iloc[:, 1]
# Out:
# index
# a    12000
# b    13000
# c    14000
# d    14000
# e    14000
# f    15000
# g    13000
# Name: 가격, dtype: int64

# %%
df.iloc[:, 0:2]
# Out:
#          메뉴     가격
# index
# a      후라이드  12000
# b      양념치킨  13000
# c      간장치킨  14000
# d      마늘치킨  14000
# e        파닭  14000
# f       닭강정  15000
# g      양반후반  13000

# %%
df.iloc[2, 0:2]
df.iloc[2, [0, 1]]
# Out:
# 메뉴     간장치킨
# 가격    14000
# Name: c, dtype: object

# %%
df
# Out:
#          메뉴     가격   호수   칼로리
# index
# a      후라이드  12000  10호  1000
# b      양념치킨  13000  10호  1400
# c      간장치킨  14000   9호  1600
# d      마늘치킨  14000   9호  1800
# e        파닭  14000  11호  1300
# f       닭강정  15000  12호  1500
# g      양반후반  13000  10호  1300

# %%
df.iloc[1:3, :]
df.iloc[[1, 2], :]
# Out:
#          메뉴     가격   호수   칼로리
# index
# b      양념치킨  13000  10호  1400
# c      간장치킨  14000   9호  1600

# %%
df.iloc[1:3, :-1] # == df.iloc[1:3, 0:3]
df.iloc[1:3, :-2] # == df.iloc[1:3, 0:2]
# Out:
#          메뉴     가격
# index
# b      양념치킨  13000
# c      간장치킨  14000

# %%
df = pd.read_csv('modudak.csv')
df
# Out:
#      메뉴     가격   호수   칼로리
# 0  후라이드  12000  10호  1000
# 1  양념치킨  13000  10호  1400
# 2  간장치킨  14000   9호  1600
# 3  마늘치킨  14000   9호  1800
# 4    파닭  14000  11호  1300
# 5   닭강정  15000  12호  1500
# 6  양반후반  13000  10호  1300

# %%
df = df.set_index(keys='메뉴')
df
# Out:
#          가격   호수   칼로리
# 메뉴
# 후라이드  12000  10호  1000
# 양념치킨  13000  10호  1400
# 간장치킨  14000   9호  1600
# 마늘치킨  14000   9호  1800
# 파닭    14000  11호  1300
# 닭강정   15000  12호  1500
# 양반후반  13000  10호  1300

# %%
df.loc['양념치킨':'마늘치킨', '호수':'칼로리']
# Out:
#        호수   칼로리
# 메뉴
# 양념치킨  10호  1400
# 간장치킨   9호  1600
# 마늘치킨   9호  1800

# %%
df.iloc[1:4, 1:]
# Out:
#        호수   칼로리
# 메뉴
# 양념치킨  10호  1400
# 간장치킨   9호  1600
# 마늘치킨   9호  1800

# %%
df = pd.read_csv('modudak.csv')
df
# Out:
#      메뉴     가격   호수   칼로리
# 0  후라이드  12000  10호  1000
# 1  양념치킨  13000  10호  1400
# 2  간장치킨  14000   9호  1600
# 3  마늘치킨  14000   9호  1800
# 4    파닭  14000  11호  1300
# 5   닭강정  15000  12호  1500
# 6  양반후반  13000  10호  1300

# %%
df['할인율'] = 0.2
df
# Out:
#      메뉴     가격   호수   칼로리  할인율
# 0  후라이드  12000  10호  1000  0.2
# 1  양념치킨  13000  10호  1400  0.2
# 2  간장치킨  14000   9호  1600  0.2
# 3  마늘치킨  14000   9호  1800  0.2
# 4    파닭  14000  11호  1300  0.2
# 5   닭강정  15000  12호  1500  0.2
# 6  양반후반  13000  10호  1300  0.2

# %%
df['할인가'] = df['가격'] * (1 - df['할인율'])
df
# Out:
#      메뉴     가격   호수   칼로리  할인율      할인가
# 0  후라이드  12000  10호  1000  0.2   9600.0
# 1  양념치킨  13000  10호  1400  0.2  10400.0
# 2  간장치킨  14000   9호  1600  0.2  11200.0
# 3  마늘치킨  14000   9호  1800  0.2  11200.0
# 4    파닭  14000  11호  1300  0.2  11200.0
# 5   닭강정  15000  12호  1500  0.2  12000.0
# 6  양반후반  13000  10호  1300  0.2  10400.0

# %%
import numpy as np
df['원산지'] = np.nan
df
# Out:
#      메뉴     가격   호수   칼로리  할인율      할인가  원산지
# 0  후라이드  12000  10호  1000  0.2   9600.0  NaN
# 1  양념치킨  13000  10호  1400  0.2  10400.0  NaN
# 2  간장치킨  14000   9호  1600  0.2  11200.0  NaN
# 3  마늘치킨  14000   9호  1800  0.2  11200.0  NaN
# 4    파닭  14000  11호  1300  0.2  11200.0  NaN
# 5   닭강정  15000  12호  1500  0.2  12000.0  NaN
# 6  양반후반  13000  10호  1300  0.2  10400.0  NaN

# %%
aiffel = ['아이펠치킨', 16000, '11호', 1200, 0.5, 8000,'국내산'] # 리스트 형식은 모든 컬럼의 값을 입력
df.loc['new'] = aiffel
df
# Out:
#         메뉴     가격   호수   칼로리  할인율      할인가  원산지
# 0     후라이드  12000  10호  1000  0.2   9600.0  NaN
# 1     양념치킨  13000  10호  1400  0.2  10400.0  NaN
# 2     간장치킨  14000   9호  1600  0.2  11200.0  NaN
# 3     마늘치킨  14000   9호  1800  0.2  11200.0  NaN
# 4       파닭  14000  11호  1300  0.2  11200.0  NaN
# 5      닭강정  15000  12호  1500  0.2  12000.0  NaN
# 6     양반후반  13000  10호  1300  0.2  10400.0  NaN
# new  아이펠치킨  16000  11호  1200  0.5   8000.0  국내산

# %%
flip = {'메뉴': '풀잎치킨', '가격': 10000, '호수': '10호'} # 디셔너리 형식은 원하는 컬럼의 값만 입력
df.loc['10'] = flip
df
# Out:
#         메뉴     가격   호수     칼로리  할인율      할인가  원산지
# 0     후라이드  12000  10호  1000.0  0.2   9600.0  NaN
# 1     양념치킨  13000  10호  1400.0  0.2  10400.0  NaN
# 2     간장치킨  14000   9호  1600.0  0.2  11200.0  NaN
# 3     마늘치킨  14000   9호  1800.0  0.2  11200.0  NaN
# 4       파닭  14000  11호  1300.0  0.2  11200.0  NaN
# 5      닭강정  15000  12호  1500.0  0.2  12000.0  NaN
# 6     양반후반  13000  10호  1300.0  0.2  10400.0  NaN
# new  아이펠치킨  16000  11호  1200.0  0.5   8000.0  국내산
# 10    풀잎치킨  10000  10호     NaN  NaN      NaN  NaN

# %%
df.loc[0, '원산지'] = '국내산'
df
# Out:
#         메뉴     가격   호수     칼로리  할인율      할인가  원산지
# 0     후라이드  12000  10호  1000.0  0.2   9600.0  국내산
# 1     양념치킨  13000  10호  1400.0  0.2  10400.0  NaN
# 2     간장치킨  14000   9호  1600.0  0.2  11200.0  NaN
# 3     마늘치킨  14000   9호  1800.0  0.2  11200.0  NaN
# 4       파닭  14000  11호  1300.0  0.2  11200.0  NaN
# 5      닭강정  15000  12호  1500.0  0.2  12000.0  NaN
# 6     양반후반  13000  10호  1300.0  0.2  10400.0  NaN
# new  아이펠치킨  16000  11호  1200.0  0.5   8000.0  국내산
# 10    풀잎치킨  10000  10호     NaN  NaN      NaN  NaN

# %%
# 파닭과 닭강정의 원산지를 "브라질"로 업데이트 단, iloc를 활용
df.iloc[4, -1:] = '브라질'
df.iloc[5, -1:] = '브라질'
df
# Out:
#         메뉴     가격   호수     칼로리  할인율      할인가  원산지
# 0     후라이드  12000  10호  1000.0  0.2   9600.0  국내산
# 1     양념치킨  13000  10호  1400.0  0.2  10400.0  NaN
# 2     간장치킨  14000   9호  1600.0  0.2  11200.0  NaN
# 3     마늘치킨  14000   9호  1800.0  0.2  11200.0  NaN
# 4       파닭  14000  11호  1300.0  0.2  11200.0  브라질
# 5      닭강정  15000  12호  1500.0  0.2  12000.0  브라질
# 6     양반후반  13000  10호  1300.0  0.2  10400.0  NaN
# new  아이펠치킨  16000  11호  1200.0  0.5   8000.0  국내산
# 10    풀잎치킨  10000  10호     NaN  NaN      NaN  NaN

# %%
df = df.replace('양반후반', '양념반후라이드반')
df
# Out:
#            메뉴     가격   호수     칼로리  할인율      할인가  원산지
# 0        후라이드  12000  10호  1000.0  0.2   9600.0  국내산
# 1        양념치킨  13000  10호  1400.0  0.2  10400.0  NaN
# 2        간장치킨  14000   9호  1600.0  0.2  11200.0  NaN
# 3        마늘치킨  14000   9호  1800.0  0.2  11200.0  NaN
# 4          파닭  14000  11호  1300.0  0.2  11200.0  브라질
# 5         닭강정  15000  12호  1500.0  0.2  12000.0  브라질
# 6    양념반후라이드반  13000  10호  1300.0  0.2  10400.0  NaN
# new     아이펠치킨  16000  11호  1200.0  0.5   8000.0  국내산
# 10       풀잎치킨  10000  10호     NaN  NaN      NaN  NaN

# %%
df = df.replace('아이펠치킨', '[인기]아이펠치킨').replace('풀잎치킨', '[베스트]풀잎치킨')
df
# Out:
#             메뉴     가격   호수     칼로리  할인율      할인가  원산지
# 0         후라이드  12000  10호  1000.0  0.2   9600.0  국내산
# 1         양념치킨  13000  10호  1400.0  0.2  10400.0  NaN
# 2         간장치킨  14000   9호  1600.0  0.2  11200.0  NaN
# 3         마늘치킨  14000   9호  1800.0  0.2  11200.0  NaN
# 4           파닭  14000  11호  1300.0  0.2  11200.0  NaN
# 5          닭강정  15000  12호  1500.0  0.2  12000.0  NaN
# 6         양반후반  13000  10호  1300.0  0.2  10400.0  NaN
# new  [인기]아이펠치킨  16000  11호  1200.0  0.5   8000.0  국내산
# 10   [베스트]풀잎치킨  10000  10호     NaN  NaN      NaN  NaN

# %%
dic = {'후라이드': '황금후라이드', '양념치킨': '승일양념치킨'}
df = df.replace(dic)
df
# Out:
#             메뉴     가격   호수     칼로리  할인율      할인가  원산지
# 0       황금후라이드  12000  10호  1000.0  0.2   9600.0  국내산
# 1       승일양념치킨  13000  10호  1400.0  0.2  10400.0  NaN
# 2         간장치킨  14000   9호  1600.0  0.2  11200.0  NaN
# 3         마늘치킨  14000   9호  1800.0  0.2  11200.0  NaN
# 4           파닭  14000  11호  1300.0  0.2  11200.0  NaN
# 5          닭강정  15000  12호  1500.0  0.2  12000.0  NaN
# 6         양반후반  13000  10호  1300.0  0.2  10400.0  NaN
# new  [인기]아이펠치킨  16000  11호  1200.0  0.5   8000.0  국내산
# 10   [베스트]풀잎치킨  10000  10호     NaN  NaN      NaN  NaN

# %%
df = df.replace(10000, 9900)
df
# Out:
#             메뉴     가격   호수     칼로리  할인율      할인가  원산지
# 0       황금후라이드  12000  10호  1000.0  0.2   9600.0  국내산
# 1       승일양념치킨  13000  10호  1400.0  0.2  10400.0  NaN
# 2         간장치킨  14000   9호  1600.0  0.2  11200.0  NaN
# 3         마늘치킨  14000   9호  1800.0  0.2  11200.0  NaN
# 4           파닭  14000  11호  1300.0  0.2  11200.0  브라질
# 5          닭강정  15000  12호  1500.0  0.2  12000.0  브라질
# 6     양념반후라이드반  13000  10호  1300.0  0.2  10400.0  NaN
# new  [인기]아이펠치킨  16000  11호  1200.0  0.5   8000.0  국내산
# 10   [베스트]풀잎치킨   9900  10호     NaN  NaN      NaN  NaN

# %%
df.to_csv('new_modudak.csv')

# %%
df = pd.read_csv('new_modudak.csv')
#df.drop('Unnamed: 0', axis=1, inplace=True)
df
df['원산지'] = df['원산지'].fillna('국내산')
df.loc[8, '칼로리'] = 1000
df.to_csv('new_modudak.csv')
