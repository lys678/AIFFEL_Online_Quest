# %% [markdown]
# <a href="https://colab.research.google.com/github/comandi1969/AIFFEL_Online_Quest/blob/main/ML_With_Python/%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D_%EA%B8%B0%EC%B4%88_%EB%85%B8%EB%93%9C10_%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 라이브러리
import pandas as pd

# %%
# 데이터 불러오기
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# train.shape # (39116, 16)
# test.shape # (9779, 15)
type(train)
# Out:
# pandas.core.frame.DataFrame

# %%
# 데이터 크기
train.shape, test.shape
# Out:
# ((39116, 16), (9779, 15))

# %%
# 데이터 샘플
display(train.head(2))
display(test.head(2))
# Out:
#          id                                            name   host_id  \
# 0  14963583          Room in South Harlem near Central Park  94219511
# 1   9458704  Large 1BR Apartment, near Times Sq (2nd Floor)  49015331
#
#   host_name neighbourhood_group   neighbourhood  latitude  longitude  \
# 0    Gilles           Manhattan          Harlem  40.80167  -73.95781
# 1     Iradj           Manhattan  Hell's Kitchen  40.76037  -73.99016
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room     70               3                  3  2019-01-01
# 1  Entire home/apt    240               2                 64  2019-06-30
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.09                               2                 0
# 1               1.68                               2               262
#          id                                               name   host_id  \
# 0  30913224  Cozy and Sunny Room Williamsburg, Luxury Building  33771081
# 1    971247                   Sunny Artist Live/Work Apartment   5308961
#
#   host_name neighbourhood_group    neighbourhood  latitude  longitude  \
# 0      Rémy            Brooklyn     Williamsburg  40.70959  -73.94652
# 1     Larry           Manhattan  Upper West Side  40.79368  -73.96487
#
#          room_type  minimum_nights  number_of_reviews last_review  \
# 0     Private room               3                  2  2019-05-08
# 1  Entire home/apt               3                159  2019-07-03
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.31                               1                 0
# 1               2.09                               1               244

# %%
# 데이터 타입
train.info()
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39116 entries, 0 to 39115
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              39116 non-null  int64
#  1   name                            39104 non-null  object
#  2   host_id                         39116 non-null  int64
#  3   host_name                       39099 non-null  object
#  4   neighbourhood_group             39116 non-null  object
#  5   neighbourhood                   39116 non-null  object
#  6   latitude                        39116 non-null  float64
#  7   longitude                       39116 non-null  float64
#  8   room_type                       39116 non-null  object
#  9   price                           39116 non-null  int64
#  10  minimum_nights                  39116 non-null  int64
#  11  number_of_reviews               39116 non-null  int64
#  12  last_review                     31122 non-null  object
#  13  reviews_per_month               31122 non-null  float64
#  14  calculated_host_listings_count  39116 non-null  int64
#  15  availability_365                39116 non-null  int64
# dtypes: float64(3), int64(7), object(6)
# memory usage: 4.8+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9779 entries, 0 to 9778
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              9779 non-null   int64
#  1   name                            9775 non-null   object
#  2   host_id                         9779 non-null   int64
#  3   host_name                       9775 non-null   object
#  4   neighbourhood_group             9779 non-null   object
#  5   neighbourhood                   9779 non-null   object
#  6   latitude                        9779 non-null   float64
#  7   longitude                       9779 non-null   float64
#  8   room_type                       9779 non-null   object
#  9   minimum_nights                  9779 non-null   int64
#  10  number_of_reviews               9779 non-null   int64
#  11  last_review                     7721 non-null   object
#  12  reviews_per_month               7721 non-null   float64
#  13  calculated_host_listings_count  9779 non-null   int64
#  14  availability_365                9779 non-null   int64
# dtypes: float64(3), int64(6), object(6)
# memory usage: 1.1+ MB

# %%
# 결측치(train)
train.isnull().sum()
# Out:
# id                                   0
# name                                12
# host_id                              0
# host_name                           17
# neighbourhood_group                  0
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       7994
# reviews_per_month                 7994
# calculated_host_listings_count       0
# availability_365                     0
# dtype: int64

# %%
# 결측치(test)
test.isnull().sum()
# Out:
# id                                   0
# name                                 4
# host_id                              0
# host_name                            4
# neighbourhood_group                  0
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       2058
# reviews_per_month                 2058
# calculated_host_listings_count       0
# availability_365                     0
# dtype: int64

# %%
# target(hist)
train['price'].hist(bins=100)
# Out:
# <Axes: >

# %%
# import numpy as np
# train['price'] = np.log1p(train['price'])
# train['price'].hist(bins=100)

# %%
# target(describe)
train['price'].describe()
# Out:
# count    39116.000000
# mean       152.751150
# std        241.752501
# min          0.000000
# 25%         69.000000
# 50%        105.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
train.head()
# Out:
#          id                                            name   host_id  \
# 0  14963583          Room in South Harlem near Central Park  94219511
# 1   9458704  Large 1BR Apartment, near Times Sq (2nd Floor)  49015331
# 2  26871281                          West Village Apartment    440022
# 3    698132             LARGE PRIVATE FLOOR IN BROOKLYN, NY   3577509
# 4  15783953    Sun-drenched apartment, 20 mins to Manhattan  12475280
#
#   host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0    Gilles           Manhattan              Harlem  40.80167  -73.95781
# 1     Iradj           Manhattan      Hell's Kitchen  40.76037  -73.99016
# 2    Petter           Manhattan        West Village  40.73001  -74.00562
# 3      Eric            Brooklyn  Bedford-Stuyvesant  40.69128  -73.93653
# 4    George            Brooklyn  Bedford-Stuyvesant  40.68899  -73.95555
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room     70               3                  3  2019-01-01
# 1  Entire home/apt    240               2                 64  2019-06-30
# 2  Entire home/apt    150              60                  1  2019-02-07
# 3  Entire home/apt     85               4                239  2019-06-26
# 4     Private room     44              28                  0         NaN
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.09                               2                 0
# 1               1.68                               2               262
# 2               0.20                               1                 0
# 3               2.89                               2                 1
# 4                NaN                               1                 0

# %%
# 결측치 컬럼 삭제(last_review)
display(train.columns)
train['last_review'].isnull().sum()
#train[['last_review', 'reviews_per_month']]
train = train.drop('last_review', axis=1)
test = test.drop('last_review', axis=1)

# train.shape # (39116, 15)
# test.shape # (9779, 14)
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# 결측치 채우기
train['reviews_per_month'] = train['reviews_per_month'].fillna(0.0)
test['reviews_per_month'] = test['reviews_per_month'].fillna(0.0)

# train.shape # (39116, 15)
# test.shape # (9779, 14)

# %%
# 결측치 확인
train.isnull().sum()
test.isnull().sum()
# Out:
# id                                0
# name                              4
# host_id                           0
# host_name                         4
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# minimum_nights                    0
# number_of_reviews                 0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
cond = train['name'].isnull() | train['host_name'].isnull()
train[cond]
# Out:
#              id                                             name    host_id  \
# 4598   10052289                                              NaN   49522403
# 5448    4209595                                              NaN   20700823
# 7644    4756856                                              NaN    1832442
# 8159     100184                                        Bienvenue     526653
# 8352    6786181                     R&S Modern Spacious Hideaway   32722063
# 8957    9787590                                              NaN   50448556
# 10625   6782407                                              NaN   31147528
# 10824   4763327              Luxurious, best location, spa inc'l   24576978
# 16160   9325951                                              NaN   33377685
# 17851  15648096            Spacious 2 bedroom close to Manhattan  100971588
# 19270  25180572                   Beautiful Cozy Studio Apt. UWS  119609345
# 21084   6992973                  1 Bedroom in Prime Williamsburg    5162530
# 21109  22275821                                              NaN   49662398
# 21672  10709846               Sunny, spacious room in Greenpoint    7822683
# 21806   4581788                                              NaN   21600904
# 22348   1449546                          Cozy Studio in Flatbush    7779204
# 23227  23660605  Private Bedroom w/ Balcony view of Central Park  177146433
# 24943  21990808               ***SLEEPING IN THE GOLDEN PLACE***  159156636
# 25901   7556587                             Sunny Room in Harlem   39608626
# 26023   4370230                                              NaN   22686810
# 27198   4183989  SPRING in the City!! Zen-Style Tranquil Bedroom     919218
# 27903   2232600                                              NaN   11395220
# 27930  12988898                                              NaN   71552588
# 30070   6360224                  Sunny, Private room in Bushwick   33134899
# 30221  30468335          LARGE Prospect Lefferts Gardens Bedroom  228750026
# 31987  14135050                                              NaN   85288337
# 36110   4446862               Charming Room in Prospect Heights!   23077718
# 36872   6292866                        Modern Quiet Gem Near All   32722063
# 38472  11553543                                Cozy Room Astoria   26138712
#
#       host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 4598    Vanessa            Brooklyn         Brownsville  40.66409  -73.92314
# 5448      Jesse           Manhattan   Greenwich Village  40.73473  -73.99244
# 7644   Carolina            Brooklyn            Bushwick  40.70046  -73.92825
# 8159        NaN              Queens      Queens Village  40.72413  -73.76133
# 8352        NaN            Brooklyn       East Flatbush  40.64345  -73.93643
# 8957     Miguel           Manhattan              Harlem  40.80316  -73.95189
# 10625  Huei-Yin            Brooklyn        Williamsburg  40.71354  -73.93882
# 10824       NaN            Brooklyn          Greenpoint  40.72035  -73.95355
# 16160  Jonathan           Manhattan      Hell's Kitchen  40.76436  -73.98573
# 17851       NaN               Bronx          Highbridge  40.83844  -73.92489
# 19270       NaN           Manhattan     Upper West Side  40.77701  -73.97667
# 21084       NaN            Brooklyn        Williamsburg  40.71838  -73.95630
# 21109  Kathleen            Brooklyn            Bushwick  40.69546  -73.92741
# 21672       NaN            Brooklyn          Greenpoint  40.73539  -73.95838
# 21806     Lucie            Brooklyn        Williamsburg  40.71370  -73.94378
# 22348       NaN            Brooklyn            Flatbush  40.64965  -73.96154
# 23227       NaN           Manhattan         East Harlem  40.79766  -73.94824
# 24943       NaN           Manhattan      Hell's Kitchen  40.75835  -73.99065
# 25901       NaN           Manhattan              Harlem  40.82929  -73.94182
# 26023   Michaël           Manhattan              Nolita  40.72046  -73.99550
# 27198       NaN           Manhattan              Harlem  40.80606  -73.95061
# 27903      Anna           Manhattan        East Village  40.73215  -73.98821
# 27930    Andrea               Bronx             Fordham  40.86032  -73.88493
# 30070       NaN            Brooklyn            Bushwick  40.70146  -73.92792
# 30221       NaN            Brooklyn            Flatbush  40.65152  -73.95271
# 31987      Jeff            Brooklyn  Bedford-Stuyvesant  40.69421  -73.93234
# 36110       NaN            Brooklyn       Crown Heights  40.67512  -73.96146
# 36872       NaN            Brooklyn       East Flatbush  40.65263  -73.93215
# 38472       NaN              Queens    Ditmars Steinway  40.77587  -73.91775
#
#              room_type  price  minimum_nights  number_of_reviews  \
# 4598      Private room     50               3                  3
# 5448   Entire home/apt    225               1                  1
# 7644      Private room     70               1                  0
# 8159      Private room     50               1                 43
# 8352   Entire home/apt    100               2                157
# 8957   Entire home/apt    300               5                  0
# 10625     Private room     45               1                  0
# 10824  Entire home/apt    195               1                  1
# 16160  Entire home/apt    190               4                  1
# 17851  Entire home/apt     75               4                 37
# 19270  Entire home/apt    180               4                  0
# 21084  Entire home/apt    145               1                  0
# 21109  Entire home/apt    110               4                  5
# 21672     Private room     55              10                  2
# 21806     Private room    150               1                  0
# 22348  Entire home/apt    100              30                 49
# 23227     Private room    139               1                  6
# 24943     Private room    120               1                 88
# 25901     Private room     28               1                  1
# 26023  Entire home/apt    215               7                  5
# 27198     Private room     86               3                 34
# 27903  Entire home/apt    200               1                 28
# 27930      Shared room    130               1                  0
# 30070     Private room     37               1                  1
# 30221     Private room     55               7                  0
# 31987     Private room     70               3                  0
# 36110     Private room     50               1                  0
# 36872  Entire home/apt     85               2                182
# 38472     Private room     45               1                  5
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 4598                0.07                               1               362
# 5448                0.02                               1                 0
# 7644                0.00                               1                 0
# 8159                0.45                               1                88
# 8352                3.18                               2               342
# 8957                0.00                               5                 0
# 10625               0.00                               1                 0
# 10824               0.02                               1                 0
# 16160               0.02                               1                 0
# 17851               1.21                               1                26
# 19270               0.00                               1                 0
# 21084               0.00                               1                 0
# 21109               0.27                               1                 0
# 21672               0.05                               1                 0
# 21806               0.00                               1                 0
# 22348               0.69                               1               342
# 23227               0.46                               1                 0
# 24943               4.93                               3                 0
# 25901               0.02                               1                 0
# 26023               0.09                               1                 0
# 27198               1.00                               1               359
# 27903               0.45                               1               341
# 27930               0.00                               1               365
# 30070               0.02                               1                 0
# 30221               0.00                               1                69
# 31987               0.00                               1                 0
# 36110               0.00                               1                 0
# 36872               3.59                               2               318
# 38472               0.13                               1                 0

# %%
# 가격 값 복사
target = train['price']
target.head()
train = train.drop('price', axis=1)
train.head()

# train.shape # (39116, 14)
# test.shape # (9779, 14)
# Out:
#          id                                            name   host_id  \
# 0  14963583          Room in South Harlem near Central Park  94219511
# 1   9458704  Large 1BR Apartment, near Times Sq (2nd Floor)  49015331
# 2  26871281                          West Village Apartment    440022
# 3    698132             LARGE PRIVATE FLOOR IN BROOKLYN, NY   3577509
# 4  15783953    Sun-drenched apartment, 20 mins to Manhattan  12475280
#
#   host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0    Gilles           Manhattan              Harlem  40.80167  -73.95781
# 1     Iradj           Manhattan      Hell's Kitchen  40.76037  -73.99016
# 2    Petter           Manhattan        West Village  40.73001  -74.00562
# 3      Eric            Brooklyn  Bedford-Stuyvesant  40.69128  -73.93653
# 4    George            Brooklyn  Bedford-Stuyvesant  40.68899  -73.95555
#
#          room_type  minimum_nights  number_of_reviews  reviews_per_month  \
# 0     Private room               3                  3               0.09
# 1  Entire home/apt               2                 64               1.68
# 2  Entire home/apt              60                  1               0.20
# 3  Entire home/apt               4                239               2.89
# 4     Private room              28                  0               0.00
#
#    calculated_host_listings_count  availability_365
# 0                               2                 0
# 1                               2               262
# 2                               1                 0
# 3                               2                 1
# 4                               1                 0

# %%
# 수치형 피처 선택

type(train)
train.info()

cols = train.select_dtypes(exclude='object').columns
cols
train[cols]

#display(cols)
#train.corr()['price'] >= 0.01

cols = ['host_id', 'latitude', 'longitude', 'minimum_nights',
       'number_of_reviews', 'reviews_per_month',
       'calculated_host_listings_count', 'availability_365']

# cols = ['host_id', 'latitude', 'longitude', 'neighbourhood', 'minimum_nights',
#        'number_of_reviews', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365']

train = train[cols]
test = test[cols]

# 레이블 인코딩
# from sklearn.preprocessing import LabelEncoder
# le = LabelEncoder()
# train['neighbourhood'] = le.fit_transform(train['neighbourhood'])
# test['neighbourhood'] = le.fit_transform(test['neighbourhood'])

# 원-핫 인코딩
# from sklearn.preprocessing import OneHotEncoder
# ohe = OneHotEncoder(sparse_output=False)

# cat = ohe.fit_transform(train[['room_type', 'neighbourhood_group', 'neighbourhood']])
# df_cat = pd.DataFrame(cat, columns=ohe.get_feature_names_out())
# train = pd.concat([train, df_cat], axis=1)
# train = train.drop(['room_type', 'neighbourhood_group', 'neighbourhood'], axis=1)


# cat = ohe.fit_transform(test[['room_type', 'neighbourhood_group', 'neighbourhood']])
# df_cat = pd.DataFrame(cat, columns=ohe.get_feature_names_out())
# test = pd.concat([test, df_cat], axis=1)
# test = test.drop(['room_type', 'neighbourhood_group', 'neighbourhood'], axis=1)

# 판다스를 이용한 원핫인코딩
# train = pd.get_dummies(train).copy()
# test = pd.get_dummies(test).copy()


# train.shape # (39116, 8)
# test.shape # (9779, 8)

# 표준화
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# train = scaler.fit_transform(train)
# test = scaler.fit_transform(test)

# 정규화
# from sklearn.preprocessing import MinMaxScaler
# scaler = MinMaxScaler()
# train = scaler.fit_transform(train)
# test = scaler.fit_transform(test)

# train.shape # (39116, 8)
# test.shape # (9779, 8)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39116 entries, 0 to 39115
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              39116 non-null  int64
#  1   name                            39104 non-null  object
#  2   host_id                         39116 non-null  int64
#  3   host_name                       39099 non-null  object
#  4   neighbourhood_group             39116 non-null  object
#  5   neighbourhood                   39116 non-null  object
#  6   latitude                        39116 non-null  float64
#  7   longitude                       39116 non-null  float64
#  8   room_type                       39116 non-null  object
#  9   minimum_nights                  39116 non-null  int64
#  10  number_of_reviews               39116 non-null  int64
#  11  reviews_per_month               39116 non-null  float64
#  12  calculated_host_listings_count  39116 non-null  int64
#  13  availability_365                39116 non-null  int64
# dtypes: float64(3), int64(6), object(5)
# memory usage: 4.2+ MB

# %%
# 검증 데이터 분리
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(train, target, test_size=0.25, random_state=0)

print(train.shape) # (39116, 8)
print(target.shape) # (39116,)
print(X_train.shape) # (29337, 8)
print(X_test.shape) # (9779, 8)
print(y_train.shape) # (29337,)
print(y_test.shape) # (9779,)

# train.shape # (39116, 8)
# test.shape # (9779, 8)
# Out:
# (39116, 8)
# (39116,)
# (29337, 8)
# (9779, 8)
# (29337,)
# (9779,)

# %%
# 머신러닝(회귀)
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

model = LinearRegression()
model.fit(X_train, y_train) # 훈련, 학습
pred = model.predict(X_test) # 예축
mean_squared_error(y_test, pred) # 검증

# train.shape # (39116, 8)
# test.shape # (9779, 8)
# Out:
# 66213.97582458047

# %%
# 릿지 회귀 (alpha=1)
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import Ridge
model = Ridge(alpha=1.0) # alpha의 기본값은 1
model.fit(X_train, y_train) # 훈련, 학습
pred = model.predict(X_test) # 예축
mean_squared_error(y_test, pred) # 검증

# train.shape # (39116, 8)
# test.shape # (9779, 8)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=3.05375e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# 66214.7300742157

# %%
# 라쏘 회귀 (alpha=1)
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import Lasso
model = Lasso(alpha=1) # alpha의 기본값은 1
model.fit(X_train, y_train) # 훈련, 학습
pred = model.predict(X_test) # 예축
mean_squared_error(y_test, pred) # 검증

# train.shape # (39116, 8)
# test.shape # (9779, 8)
# Out:
# 66844.54426556612

# %%
# 엘리스틱 회귀 (alpha=1)
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import ElasticNet
model = ElasticNet(alpha=1) # alpha의 기본값은 1
model.fit(X_train, y_train) # 훈련, 학습
pred = model.predict(X_test) # 예축
mean_squared_error(y_test, pred) # 검증

# train.shape # (39116, 8)
# test.shape # (9779, 8)
# Out:
# 67641.86518821795

# %%
# 랜덤포레스트 회귀
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
model = RandomForestRegressor(random_state=0)

model.fit(X_train, y_train)
pred = model.predict(X_test)

mean_squared_error(y_test, pred) # MSE

# train.shape # (39116, 8)
# test.shape # (9779, 8)
# Out:
# 57981.96734713161

# %%
# xgboost 회귀
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error

y_test.shape # (9779,)
X_test.shape # (9779, 8)

model = XGBRegressor(random_state=0)
model.fit(X_train, y_train)
pred = model.predict(X_test)
mean_squared_error(y_test, pred) # MSE

# train.shape # (39116, 8)
# test.shape # (9779, 8)
# Out:
# 62012.34247579781

# %%
# test 데이터 예측 및 평가
y_test = pd.read_csv('y_test.csv')

# y_test.shape # (9779, 1)
# train.shape # (39116, 8)
# test.shape # (9779, 8)

# Xgboost
pred = model.predict(test)
my_score = mean_squared_error(y_test, pred)
my_score
# Out:
# 48489.935890235276

# %%
# baseline score(mse 51xxx) 보다 점수가 낮게 나오도록 도전해 보세요!
print(f'나의 점수는 (MSE {my_score})입니다.')
# 나의 점수는 (MSE 50491.801331459596)입니다. <= 표준화만 적용
# 나의 점수는 (MSE 54059.38283334756)입니다. <= 정규화만 적용
# Out:
# 나의 점수는 (MSE 48489.935890235276)입니다.
