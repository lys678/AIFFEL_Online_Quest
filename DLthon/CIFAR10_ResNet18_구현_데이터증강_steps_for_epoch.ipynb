# %% [markdown]
# <a href="https://colab.research.google.com/github/comandi1969/AIFFEL_Online_Quest/blob/main/DLthon/CIFAR10_ResNet18_%EA%B5%AC%ED%98%84_%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%A6%9D%EA%B0%95_steps_for_epoch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, ReLU, GlobalAveragePooling2D, Dense, Add
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# 데이터 로딩 및 전처리
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# 클래스 레이블을 원핫인코딩으로 변환
from tensorflow.keras.utils import to_categorical
num_classes = 10  # CIFAR-10은 10개의 클래스로 구성됨
y_train_one_hot = to_categorical(y_train, num_classes)
y_test_one_hot = to_categorical(y_test, num_classes)

# %%
# 이미지 데이터 증강
# ImageDataGenerator를 사용하여 이미지 데이터 증강을 적용하면 모델의 과적합을 줄이고 일반화 성능을 향상시킬 수 있습니다.
from tensorflow.keras.preprocessing.image import ImageDataGenerator
datagen = ImageDataGenerator(
    rotation_range=15,       # 이미지 회전 범위 (도)
    width_shift_range=0.1,  # 수평 방향으로 이동 범위 (전체 너비의 비율)
    height_shift_range=0.1, # 수직 방향으로 이동 범위 (전체 높이의 비율)
    shear_range=0.1,        # 전단 변환 범위
    zoom_range=0.1,         # 확대/축소 범위
    horizontal_flip=True,   # 수평 방향으로 뒤집기
    vertical_flip=False,   # 수직 방향으로 뒤집기
    fill_mode='nearest'     # 빈 공간을 어떻게 채울지 ('nearest', 'constant', 'reflect', 'wrap' 중 선택)
)
datagen.fit(x_train)

# %%
# 로그 디렉터리 설정, 콜백함수 정의
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, LearningRateScheduler
import os

log_dir = "./logs"
if not os.path.exists(log_dir):
    os.mkdir(log_dir)

def scheduler(epoch, lr):
    if epoch < 10:
        return lr
    else:
        return lr * 0.95  # decrease the learning rate after 10 epochs

tensorboard = TensorBoard(log_dir=log_dir, histogram_freq=1)
checkpoint = ModelCheckpoint('cifar10_model.h5', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
early_stopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1, restore_best_weights=True)
lr_scheduler = LearningRateScheduler(scheduler, verbose=1)

# %%
def identity_block(X, filters, kernel_size=3):
    F1, F2 = filters
    X_shortcut = X

    # First component
    X = Conv2D(F1, (kernel_size, kernel_size), padding='same')(X)
    X = BatchNormalization()(X)
    X = ReLU()(X)

    # Second component
    X = Conv2D(F2, (kernel_size, kernel_size), padding='same')(X)
    X = BatchNormalization()(X)

    # Add shortcut value
    X = Add()([X, X_shortcut])
    X = ReLU()(X)

    return X

def convolutional_block(X, filters, kernel_size=3, s=2):
    F1, F2 = filters
    X_shortcut = X

    # First component
    X = Conv2D(F1, (kernel_size, kernel_size), strides=(s, s), padding='same')(X)
    X = BatchNormalization()(X)
    X = ReLU()(X)

    # Second component
    X = Conv2D(F2, (kernel_size, kernel_size), padding='same')(X)
    X = BatchNormalization()(X)

    # Shortcut path
    X_shortcut = Conv2D(F2, (1, 1), strides=(s, s), padding='valid')(X_shortcut)
    X_shortcut = BatchNormalization()(X_shortcut)

    # Add shortcut value
    X = Add()([X, X_shortcut])
    X = ReLU()(X)

    return X

def ResNet18_CIFAR10(input_shape, num_classes):
    inputs = Input(shape=input_shape)

    # Initial convolution
    X = Conv2D(64, (3, 3), strides=(1, 1), padding='same')(inputs)
    X = BatchNormalization()(X)
    X = ReLU()(X)

    # ResNet blocks
    X = identity_block(X, [64, 64])
    X = identity_block(X, [64, 64])

    X = convolutional_block(X, [128, 128])
    X = identity_block(X, [128, 128])

    X = convolutional_block(X, [256, 256])
    X = identity_block(X, [256, 256])

    X = convolutional_block(X, [512, 512])
    X = identity_block(X, [512, 512])

    X = GlobalAveragePooling2D()(X)
    outputs = Dense(num_classes, activation='softmax')(X)

    model = Model(inputs=inputs, outputs=outputs)

    return model

# %%
# Example of creating a ResNet18 model for CIFAR10 dataset
model = ResNet18_CIFAR10((32, 32, 3), 10)
model.summary()

# 모델 컴파일
model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
#model.compile(optimizer=SGD(learning_rate=0.01, momentum=0.9), loss='categorical_crossentropy', metrics=['accuracy'])

# 콜백함수
from tensorflow.keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=20, verbose=1, restore_best_weights=True)
callbacks_list = [early_stopping, lr_scheduler]

# steps_per_epoch 설정
# 데이터 파이프라인을 통해 2배의 훈련 데아터셋을 학습
steps_per_epoch = (len(x_train) // 128) * 2

# 모델 훈련
history = model.fit(datagen.flow(x_train, y_train_one_hot),
                    epochs=200,
                    steps_per_epoch = steps_per_epoch,
                    validation_data=(x_test, y_test_one_hot),
                    shuffle=True,
                    callbacks=callbacks_list)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 64)   1792        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 32, 32, 64)   256         conv2d[0][0]
# __________________________________________________________________________________________________
# re_lu (ReLU)                    (None, 32, 32, 64)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 64)   36928       re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# re_lu_1 (ReLU)                  (None, 32, 32, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 64)   36928       re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 32, 32, 64)   0           batch_normalization_2[0][0]
#                                                                  re_lu[0][0]
# __________________________________________________________________________________________________
# re_lu_2 (ReLU)                  (None, 32, 32, 64)   0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 64)   36928       re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 64)   256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# re_lu_3 (ReLU)                  (None, 32, 32, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 64)   36928       re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 64)   0           batch_normalization_4[0][0]
#                                                                  re_lu_2[0][0]
# __________________________________________________________________________________________________
# re_lu_4 (ReLU)                  (None, 32, 32, 64)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 16, 16, 128)  73856       re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 16, 16, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# re_lu_5 (ReLU)                  (None, 16, 16, 128)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 128)  147584      re_lu_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 128)  8320        re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 16, 128)  512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 128)  512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 16, 16, 128)  0           batch_normalization_6[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# re_lu_6 (ReLU)                  (None, 16, 16, 128)  0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 128)  147584      re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 128)  512         conv2d_8[0][0]
# __________________________________________________________________________________________________
# re_lu_7 (ReLU)                  (None, 16, 16, 128)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 128)  147584      re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 128)  512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 16, 16, 128)  0           batch_normalization_9[0][0]
#                                                                  re_lu_6[0][0]
# __________________________________________________________________________________________________
# re_lu_8 (ReLU)                  (None, 16, 16, 128)  0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 8, 8, 256)    295168      re_lu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 8, 8, 256)    1024        conv2d_10[0][0]
# __________________________________________________________________________________________________
# re_lu_9 (ReLU)                  (None, 8, 8, 256)    0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 8, 8, 256)    590080      re_lu_9[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 8, 8, 256)    33024       re_lu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 8, 8, 256)    1024        conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 8, 8, 256)    1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 8, 8, 256)    0           batch_normalization_11[0][0]
#                                                                  batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# re_lu_10 (ReLU)                 (None, 8, 8, 256)    0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 8, 8, 256)    590080      re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 8, 8, 256)    1024        conv2d_13[0][0]
# __________________________________________________________________________________________________
# re_lu_11 (ReLU)                 (None, 8, 8, 256)    0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 8, 8, 256)    590080      re_lu_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 8, 8, 256)    1024        conv2d_14[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 8, 8, 256)    0           batch_normalization_14[0][0]
#                                                                  re_lu_10[0][0]
# __________________________________________________________________________________________________
# re_lu_12 (ReLU)                 (None, 8, 8, 256)    0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 4, 4, 512)    1180160     re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 4, 4, 512)    2048        conv2d_15[0][0]
# __________________________________________________________________________________________________
# re_lu_13 (ReLU)                 (None, 4, 4, 512)    0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 4, 4, 512)    2359808     re_lu_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 4, 4, 512)    131584      re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 4, 4, 512)    2048        conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 4, 4, 512)    2048        conv2d_17[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 4, 4, 512)    0           batch_normalization_16[0][0]
#                                                                  batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# re_lu_14 (ReLU)                 (None, 4, 4, 512)    0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 4, 4, 512)    2359808     re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 4, 4, 512)    2048        conv2d_18[0][0]
# __________________________________________________________________________________________________
# re_lu_15 (ReLU)                 (None, 4, 4, 512)    0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 4, 4, 512)    2359808     re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 4, 4, 512)    2048        conv2d_19[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 4, 4, 512)    0           batch_normalization_19[0][0]
#                                                                  re_lu_14[0][0]
# __________________________________________________________________________________________________
# re_lu_16 (ReLU)                 (None, 4, 4, 512)    0           add_7[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 512)          0           re_lu_16[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           5130        global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 11,188,362
# Trainable params: 11,178,762
# Non-trainable params: 9,600
# __________________________________________________________________________________________________
# Epoch 1/200
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# 780/780 [==============================] - 40s 45ms/step - loss: 1.5846 - accuracy: 0.4279 - val_loss: 1.8483 - val_accuracy: 0.4497
# Epoch 2/200
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# 780/780 [==============================] - 34s 44ms/step - loss: 1.1721 - accuracy: 0.5813 - val_loss: 1.7793 - val_accuracy: 0.4867
# Epoch 3/200
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# 780/780 [==============================] - 35s 44ms/step - loss: 0.9558 - accuracy: 0.6657 - val_loss: 1.1285 - val_accuracy: 0.6310
# Epoch 4/200
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# 780/780 [==============================] - 34s 44ms/step - loss: 0
#
# Epoch 00047: LearningRateScheduler setting learning rate to 0.0001498902252933476.
# 780/780 [==============================] - 34s 44ms/step - loss: 0.1028 - accuracy: 0.9643 - val_loss: 0.2877 - val_accuracy: 0.9139
# Epoch 48/200
#
# Epoch 00048: LearningRateScheduler setting learning rate to 0.00014239571610232815.
# 780/780 [==============================] - 34s 44ms/step - loss: 0.0986 - accuracy: 0.9662 - val_loss: 0.3158 - val_accuracy: 0.9095
# Epoch 49/200
#
# Epoch 00049: LearningRateScheduler setting learning rate to 0.00013527592891477978.
# 780/780 [==============================] - 34s 44ms/step - loss: 0.0964 - accuracy: 0.9656 - val_loss: 0.2939 - val_accuracy: 0.9152
# Epoch 50/200
#
# Epoch 00050: LearningRateScheduler setting learning rate to 0.00012851213177782482.
# 780/780 [==============================] - 34s 44ms/step - loss: 0.0920 - accuracy: 0.9674 - val_loss: 0.2764 - val_accuracy: 0.9173
# Epoch 51/200
#
# Epoch 00051: LearningRateScheduler setting learning rate to 0.00012208651896798982.
# 780/780 [==============================] - 34s 44ms/step - loss: 0.0939 - accuracy: 0.9664 - val_loss: 0.2811 - val_accuracy: 0.9154
# Epoch 52/200
#
# Epoch 00052: LearningRateScheduler setting learning rate to 0.00011598219716688617.
# 780/780 [==============================] - 34s 44ms/step - loss: 0.0892 - accuracy: 0.9686 - val_loss: 0.2829 - val_accuracy: 0.9162
# Epoch 53/200
#
# Epoch 00053: LearningRateScheduler setting learning rate to 0.00011018308869097381.
# 780/780 [==============================] - 35s 44ms/step - loss: 0.0893 - accuracy: 0.9682 - val_loss: 0.2762 - val_accuracy: 0.9195
# Epoch 54/200
#
# Epoch 00054: LearningRateScheduler setting learning rate to 0.00010467393149156123.
# 780/780 [==============================] - 34s 44ms/step - loss: 0.0831 - accuracy: 0.9713 - val_loss: 0.2847 - val_accuracy: 0.9160
# Epoch 55/200
#
# Epoch 00055: LearningRateScheduler setting learning rate to 9.944023768184706e-05.
# 780/780 [==============================] - 35s 44ms/step - loss: 0.0784 - accuracy: 0.9726 - val_loss: 0.2905 - val_accuracy: 0.9160
# Epoch 56/200
#
# Epoch 00056: LearningRateScheduler setting learning rate to 9.446822441532275e-05.
# 780/780 [==============================] - 34s 44ms/step - loss: 0.0810 - accuracy: 0.9716 - val_loss: 0.3027 - val_accuracy: 0.9155
# Epoch 57/200
#
# Epoch 00057: LearningRateScheduler setting learning rate to 8.974481388577259e-05.
# 780/780 [==============================] - 34s 44ms/step - loss: 0.0755 - accuracy: 0.9746 - val_loss: 0.2840 - val_accuracy: 0.9171
# Epoch 58/200
#
# Epoch 00058: LearningRateScheduler setting learning rate to 8.525757111783605e-05.
# 780/780 [==============================] - 35s 44ms/step - loss: 0.0716 - accuracy: 0.9745 - val_loss: 0.2953 - val_accuracy: 0.9170
# Epoch 59/200
#
# Epoch 00059: LearningRateScheduler setting learning rate to 8.099469014268834e-05.
# 780/780 [==============================] - 34s 44ms/step - loss: 0.0726 - accuracy: 0.9744 - val_loss: 0.2862 - val_accuracy: 0.9191
# Epoch 60/200
#
# Epoch 00060: LearningRateScheduler setting learning rate to 7.694495252508204e-05.
# 780/780 [==============================] - 34s 44ms/step - loss: 0.0750 - accuracy: 0.9750 - val_loss: 0.2827 - val_accuracy: 0.9205
# Epoch 61/200
#
# Epoch 00061: LearningRateScheduler setting learning rate to 7.309770662686787e-05.
# 780/780 [==============================] - 34s 44ms/step - loss: 0.0665 - accuracy: 0.9770 - val_loss: 0.2781 - val_accuracy: 0.9197
# Epoch 62/200
#
# Epoch 00062: LearningRateScheduler setting learning rate to 6.944281922187656e-05.
# 780/780 [==============================] - 34s 44ms/step - loss: 0.0673 - accuracy: 0.9769 - val_loss: 0.2882 - val_accuracy: 0.9210
# Restoring model weights from the end of the best epoch.
# Epoch 00062: early stopping

# %%
# 학습 및 검증 정확도와 손실을 그래프로 표시
def plot_history(history):
    plt.figure(figsize=(12, 4))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.legend()
    plt.title('Training and Validation Accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.legend()
    plt.title('Training and Validation Loss')

    plt.show()

# 모델 학습 이후에 이 함수를 호출
plot_history(history)
