# %% [markdown]
# <a href="https://colab.research.google.com/github/comandi1969/AIFFEL_Online_Quest/blob/main/DLthon/CIFAR10_VGG16_%EA%B5%AC%ED%98%84_%EC%97%85%EC%8A%A4%EC%BC%80%EC%9D%BC%EB%A7%81_%EC%A6%9D%EA%B0%95_steps_for_epoch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
from PIL import Image
from tensorflow.keras.preprocessing.image import ImageDataGenerator


# 1. 데이터 로드
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 2s 0us/step

# %%
# CIFAR-10 클래스 이름
class_names = ["airplane", "automobile", "bird", "cat", "deer", "dog", "frog", "horse", "ship", "truck"]

# %%
# 2. 데이터 전처리
# train_images = train_images.astype('float32') / 255.0
# test_images = test_images.astype('float32') / 255.0

# 이미지 업스케일링 64 X 64
def resize_pil_images(images, target_height=64, target_width=64):
    """Resizes a batch of images using PIL."""
    resized_images = []
    for img in images:
        pil_img = Image.fromarray(img.astype(np.uint8))
        pil_img_resized = pil_img.resize((target_width, target_height), Image.BILINEAR)
        resized_images.append(np.array(pil_img_resized))
    return np.array(resized_images)

# Resize CIFAR-10 images
resized_train_images = resize_pil_images(train_images)
resized_test_images = resize_pil_images(test_images)

# resized_train_images = resized_train_images.astype('float32') / 255.0
# resized_test_images = resized_test_images.astype('float32') / 255.0

# %%
# Visualization function (same as before)
def plot_original_and_resized(original, resized, index):
    plt.figure(figsize=(6, 3))
    plt.subplot(1, 2, 1)
    plt.imshow(original[index].astype(np.uint8))
    plt.title('Original Image')
    plt.axis('off')
    plt.subplot(1, 2, 2)
    plt.imshow(resized[index].astype(np.uint8))
    plt.title('Resized Image')
    plt.axis('off')
    plt.tight_layout()
    plt.show()

# Visualize an example
plot_original_and_resized(train_images, resized_train_images, 0)

# %%
# 클래스 레이블을 원핫인코딩으로 변환
from tensorflow.keras.utils import to_categorical

num_classes = 10  # CIFAR-10은 10개의 클래스로 구성됨
train_labels_one_hot = to_categorical(train_labels, num_classes)
test_labels_one_hot = to_categorical(test_labels, num_classes)

# %%
# 4. 이미지 데이터 증강
datagen = ImageDataGenerator(
    rotation_range=15,       # 이미지 회전 범위 (도)
    width_shift_range=0.1,  # 수평 방향으로 이동 범위 (전체 너비의 비율)
    height_shift_range=0.1, # 수직 방향으로 이동 범위 (전체 높이의 비율)
    shear_range=0.1,        # 전단 변환 범위
    zoom_range=0.1,         # 확대/축소 범위
    horizontal_flip=True,   # 수평 방향으로 뒤집기
    fill_mode='nearest'     # 빈 공간을 어떻게 채울지 ('nearest', 'constant', 'reflect', 'wrap' 중 선택)
)
datagen.fit(resized_train_images)

# %%
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, LearningRateScheduler
import os

# 로그 디렉터리 설정
log_dir = "./logs"
if not os.path.exists(log_dir):
    os.mkdir(log_dir)

tensorboard = TensorBoard(log_dir=log_dir, histogram_freq=1)
checkpoint = ModelCheckpoint('cifar10_model.h5', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
early_stopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1, restore_best_weights=True)

def scheduler(epoch, lr):
    if epoch < 10:
        return lr
    else:
        return lr * 0.95  # decrease the learning rate after 10 epochs

lr_scheduler = LearningRateScheduler(scheduler, verbose=1)

# %%
# VGG16 model for CIFAR10
model = Sequential([
    # First two convolutional layers
    Conv2D(64, (3, 3), activation='relu', padding='same', input_shape=(64, 64, 3)),
    Conv2D(64, (3, 3), activation='relu', padding='same'),
    MaxPooling2D((2, 2)),

    # Next two convolutional layers
    Conv2D(128, (3, 3), activation='relu', padding='same'),
    Conv2D(128, (3, 3), activation='relu', padding='same'),
    MaxPooling2D((2, 2)),

    # Next three convolutional layers
    Conv2D(256, (3, 3), activation='relu', padding='same'),
    Conv2D(256, (3, 3), activation='relu', padding='same'),
    Conv2D(256, (3, 3), activation='relu', padding='same'),
    MaxPooling2D((2, 2)),

    # Next three convolutional layers
    Conv2D(512, (3, 3), activation='relu', padding='same'),
    Conv2D(512, (3, 3), activation='relu', padding='same'),
    Conv2D(512, (3, 3), activation='relu', padding='same'),
    MaxPooling2D((2, 2)),

    # Flatten and fully connected layers
    Flatten(),
    Dense(4096, activation='relu'),
    Dense(4096, activation='relu'),
    Dense(10, activation='softmax')  # 10 classes for CIFAR10
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()

# steps_per_epoch 설정
# 데이터 파이프라인을 통해 2배의 훈련 데아터셋을 학습
steps_per_epoch = (len(resized_train_images) // 128) * 2

# 학습, 원핫인코딩된 레이블로 레이블 바꿔주기
callbacks_list = [early_stopping, lr_scheduler]

history = model.fit(datagen.flow(resized_train_images, train_labels_one_hot),
                    epochs=200,
                    steps_per_epoch = steps_per_epoch,
                    validation_data=(resized_test_images, test_labels_one_hot),
                    shuffle=True,
                    callbacks=callbacks_list)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 64, 64, 64)        1792
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 64)        36928
#
#  max_pooling2d (MaxPooling2D  (None, 32, 32, 64)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 128)       73856
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 128)       147584
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 16, 128)      0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 256)       295168
#
#  conv2d_5 (Conv2D)           (None, 16, 16, 256)       590080
#
#  conv2d_6 (Conv2D)           (None, 16, 16, 256)       590080
#
#  max_pooling2d_2 (MaxPooling  (None, 8, 8, 256)        0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 8, 8, 512)         1180160
#
#  conv2d_8 (Conv2D)           (None, 8, 8, 512)         2359808
#
#  conv2d_9 (Conv2D)           (None, 8, 8, 512)         2359808
#
#  max_pooling2d_3 (MaxPooling  (None, 4, 4, 512)        0
#  2D)
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 4096)              33558528
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  dense_2 (Dense)             (None, 10)                40970
#
# =================================================================
# Total params: 58,016,074
# Trainable params: 58,016,074
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 1/200
# 780/780 [==============================] - 68s 68ms/step - loss: 2.7557 - accuracy: 0.1652 - val_loss: 1.9634 - val_accuracy: 0.2698 - lr: 0.0010
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 2/200
# 780/780 [==============================] - 52s 66ms/step - loss: 1.8833 - accuracy: 0.2905 - val_loss: 1.7275 - val_accuracy: 0.3530 - lr: 0.0010
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 3/200
# 780/780 [==============================] - 49s 63ms/step - loss: 1.7626 - accuracy: 0.3392 - val_loss: 1.6442 - val_accuracy: 0.3702 - lr: 0.0010
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 4/200
# 780/780 [==============================] - 51s 66ms/step - loss: 1.6821 - accuracy: 0.3722 - val_loss: 1.5526 - val_accuracy: 0.4172 - lr: 0.0010
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 5/200
# 780/780 [==============================] - 52s 66ms/step - loss: 1.6088 - accuracy: 0.4036 - val_loss: 1.4982 - val_accuracy: 0.4386 - lr: 0.0010
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 6/200
# 780/780 [==============================] - 51s 66ms/step - loss: 1.5703 - accuracy: 0.4247 - val_loss: 1.4729 - val_accuracy: 0.4542 - lr: 0.0010
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 7/200
# 780/780 [==============================] - 51s 66ms/step - loss: 1.5025 - accuracy: 0.4481 - val_loss: 1.4300 - val_accuracy: 0.4798 - lr: 0.0010
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 8/200
# 780/780 [==============================] - 50s 64ms/step - loss: 1.4485 - accuracy: 0.4733 - val_loss: 1.3791 - val_accuracy: 0.5065 - lr: 0.0010
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 9/200
# 780/780 [==============================] - 50s 65ms/step - loss: 1.3930 - accuracy: 0.4945 - val_loss: 1.2563 - val_accuracy: 0.5402 - lr: 0.0010
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 10/200
# 780/780 [==============================] - 49s 63ms/step - loss: 1.3579 - accuracy: 0.5100 - val_loss: 1.2876 - val_accuracy: 0.5395 - lr: 0.0010
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.0009500000451225787.
# Epoch 11/200
# 780/780 [==============================] - 49s 63ms/step - loss: 1.3212 - accuracy: 0.5197 - val_loss: 1.1968 - val_accuracy: 0.5686 - lr: 9.5000e-04
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.
#
# Epoch 47: LearningRateScheduler setting learning rate to 0.0001498902252933476.
# Epoch 47/200
# 780/780 [==============================] - 51s 65ms/step - loss: 0.5708 - accuracy: 0.7997 - val_loss: 0.6203 - val_accuracy: 0.7907 - lr: 1.4989e-04
#
# Epoch 48: LearningRateScheduler setting learning rate to 0.00014239571610232815.
# Epoch 48/200
# 780/780 [==============================] - 49s 63ms/step - loss: 0.5698 - accuracy: 0.7993 - val_loss: 0.6262 - val_accuracy: 0.7887 - lr: 1.4240e-04
#
# Epoch 49: LearningRateScheduler setting learning rate to 0.00013527592891477978.
# Epoch 49/200
# 780/780 [==============================] - 51s 65ms/step - loss: 0.5565 - accuracy: 0.8014 - val_loss: 0.6300 - val_accuracy: 0.7905 - lr: 1.3528e-04
#
# Epoch 50: LearningRateScheduler setting learning rate to 0.00012851213177782482.
# Epoch 50/200
# 780/780 [==============================] - 49s 63ms/step - loss: 0.5524 - accuracy: 0.8068 - val_loss: 0.6142 - val_accuracy: 0.7954 - lr: 1.2851e-04
#
# Epoch 51: LearningRateScheduler setting learning rate to 0.00012208651896798982.
# Epoch 51/200
# 780/780 [==============================] - 51s 65ms/step - loss: 0.5501 - accuracy: 0.8069 - val_loss: 0.6215 - val_accuracy: 0.7921 - lr: 1.2209e-04
#
# Epoch 52: LearningRateScheduler setting learning rate to 0.00011598219716688617.
# Epoch 52/200
# 780/780 [==============================] - 49s 63ms/step - loss: 0.5360 - accuracy: 0.8103 - val_loss: 0.6053 - val_accuracy: 0.8037 - lr: 1.1598e-04
#
# Epoch 53: LearningRateScheduler setting learning rate to 0.00011018308869097381.
# Epoch 53/200
# 780/780 [==============================] - 51s 65ms/step - loss: 0.5349 - accuracy: 0.8125 - val_loss: 0.6119 - val_accuracy: 0.7948 - lr: 1.1018e-04
#
# Epoch 54: LearningRateScheduler setting learning rate to 0.00010467393149156123.
# Epoch 54/200
# 780/780 [==============================] - 52s 67ms/step - loss: 0.5208 - accuracy: 0.8139 - val_loss: 0.5876 - val_accuracy: 0.8037 - lr: 1.0467e-04
#
# Epoch 55: LearningRateScheduler setting learning rate to 9.944023768184706e-05.
# Epoch 55/200
# 780/780 [==============================] - 51s 65ms/step - loss: 0.5200 - accuracy: 0.8163 - val_loss: 0.5915 - val_accuracy: 0.7999 - lr: 9.9440e-05
#
# Epoch 56: LearningRateScheduler setting learning rate to 9.446822441532275e-05.
# Epoch 56/200
# 780/780 [==============================] - 50s 64ms/step - loss: 0.5152 - accuracy: 0.8163 - val_loss: 0.6070 - val_accuracy: 0.7967 - lr: 9.4468e-05
#
# Epoch 57: LearningRateScheduler setting learning rate to 8.974481388577259e-05.
# Epoch 57/200
# 780/780 [==============================] - 50s 64ms/step - loss: 0.5153 - accuracy: 0.8206 - val_loss: 0.6144 - val_accuracy: 0.7965 - lr: 8.9745e-05
#
# Epoch 58: LearningRateScheduler setting learning rate to 8.525757111783605e-05.
# Epoch 58/200
# 780/780 [==============================] - 50s 64ms/step - loss: 0.5068 - accuracy: 0.8214 - val_loss: 0.5820 - val_accuracy: 0.8077 - lr: 8.5258e-05
#
# Epoch 59: LearningRateScheduler setting learning rate to 8.099469014268834e-05.
# Epoch 59/200
# 780/780 [==============================] - 51s 66ms/step - loss: 0.4914 - accuracy: 0.8273 - val_loss: 0.5932 - val_accuracy: 0.8059 - lr: 8.0995e-05
#
# Epoch 60: LearningRateScheduler setting learning rate to 7.694495252508204e-05.
# Epoch 60/200
# 780/780 [==============================] - 52s 66ms/step - loss: 0.4908 - accuracy: 0.8271 - val_loss: 0.5786 - val_accuracy: 0.8085 - lr: 7.6945e-05
#
# Epoch 61: LearningRateScheduler setting learning rate to 7.309770662686787e-05.
# Epoch 61/200
# 780/780 [==============================] - 50s 64ms/step - loss: 0.4862 - accuracy: 0.8281 - val_loss: 0.5871 - val_accuracy: 0.8071 - lr: 7.3098e-05
#
# Epoch 62: LearningRateScheduler setting learning rate to 6.944281922187656e-05.
# Epoch 62/200
# 780/780 [==============================] - 51s 66ms/step - loss: 0.4807 - accuracy: 0.8299 - val_loss: 0.5865 - val_accuracy: 0.8063 - lr: 6.9443e-05
#
# Epoch 63: LearningRateScheduler setting learning rate to 6.597067549591884e-05.
# Epoch 63/200
# 780/780 [==============================] - 50s 64ms/step - loss: 0.4815 - accuracy: 0.8307 - val_loss: 0.5881 - val_accuracy: 0.8113 - lr: 6.5971e-05
#
# Epoch 64: LearningRateScheduler setting learning rate to 6.267214448598679e-05.
# Epoch 64/200
# 780/780 [==============================] - 51s 66ms/step - loss: 0.4783 - accuracy: 0.8315 - val_loss: 0.5817 - val_accuracy: 0.8074 - lr: 6.2672e-05
#
# Epoch 65: LearningRateScheduler setting learning rate to 5.953853760729544e-05.
# Epoch 65/200
# 780/780 [==============================] - 51s 66ms/step - loss: 0.4687 - accuracy: 0.8355 - val_loss: 0.5792 - val_accuracy: 0.8080 - lr: 5.9539e-05
#
# Epoch 66: LearningRateScheduler setting learning rate to 5.656161210936261e-05.
# Epoch 66/200
# 780/780 [==============================] - 50s 64ms/step - loss: 0.4675 - accuracy: 0.8374 - val_loss: 0.5750 - val_accuracy: 0.8106 - lr: 5.6562e-05
#
# Epoch 67: LearningRateScheduler setting learning rate to 5.373353305913042e-05.
# Epoch 67/200
# 780/780 [==============================] - 52s 66ms/step - loss: 0.4602 - accuracy: 0.8366 - val_loss: 0.5734 - val_accuracy: 0.8109 - lr: 5.3734e-05
#
# Epoch 68: LearningRateScheduler setting learning rate to 5.104685606056591e-05.
# Epoch 68/200
# 780/780 [==============================] - 50s 64ms/step - loss: 0.4556 - accuracy: 0.8369 - val_loss: 0.5792 - val_accuracy: 0.8109 - lr: 5.1047e-05
#
# Epoch 69: LearningRateScheduler setting learning rate to 4.849451343034161e-05.
# Epoch 69/200
# 780/780 [==============================] - 50s 64ms/step - loss: 0.4663 - accuracy: 0.8338 - val_loss: 0.5740 - val_accuracy: 0.8146 - lr: 4.8495e-05
#
# Epoch 70: LearningRateScheduler setting learning rate to 4.606978654919658e-05.
# Epoch 70/200
# 780/780 [==============================] - 51s 66ms/step - loss: 0.4608 - accuracy: 0.8381 - val_loss: 0.5694 - val_accuracy: 0.8117 - lr: 4.6070e-05
#
# Epoch 71: LearningRateScheduler setting learning rate to 4.3766295493696814e-05.
# Epoch 71/200
# 780/780 [==============================] - 49s 63ms/step - loss: 0.4521 - accuracy: 0.8405 - val_loss: 0.5752 - val_accuracy: 0.8129 - lr: 4.3766e-05
#
# Epoch 72: LearningRateScheduler setting learning rate to 4.1577981755835934e-05.
# Epoch 72/200
# 780/780 [==============================] - 51s 66ms/step - loss: 0.4451 - accuracy: 0.8406 - val_loss: 0.5738 - val_accuracy: 0.8154 - lr: 4.1578e-05
#
# Epoch 73: LearningRateScheduler setting learning rate to 3.949908405047608e-05.
# Epoch 73/200
# 780/780 [==============================] - 50s 64ms/step - loss: 0.4444 - accuracy: 0.8439 - val_loss: 0.5663 - val_accuracy: 0.8183 - lr: 3.9499e-05
#
# Epoch 74: LearningRateScheduler setting learning rate to 3.752413140318822e-05.
# Epoch 74/200
# 780/780 [==============================] - 52s 66ms/step - loss: 0.4392 - accuracy: 0.8423 - val_loss: 0.5712 - val_accuracy: 0.8170 - lr: 3.7524e-05
#
# Epoch 75: LearningRateScheduler setting learning rate to 3.564792586985277e-05.
# Epoch 75/200
# 780/780 [==============================] - 50s 64ms/step - loss: 0.4405 - accuracy: 0.8436 - val_loss: 0.5810 - val_accuracy: 0.8160 - lr: 3.5648e-05
#
# Epoch 76: LearningRateScheduler setting learning rate to 3.3865528712340166e-05.
# Epoch 76/200
# 780/780 [==============================] - 50s 64ms/step - loss: 0.4371 - accuracy: 0.8457 - val_loss: 0.5724 - val_accuracy: 0.8130 - lr: 3.3866e-05
#
# Epoch 77: LearningRateScheduler setting learning rate to 3.217225348635111e-05.
# Epoch 77/200
# 780/780 [==============================] - 51s 66ms/step - loss: 0.4334 - accuracy: 0.8447 - val_loss: 0.5787 - val_accuracy: 0.8132 - lr: 3.2172e-05
#
# Epoch 78: LearningRateScheduler setting learning rate to 3.0563641848857516e-05.
# Epoch 78/200
# 780/780 [==============================] - 52s 66ms/step - loss: 0.4305 - accuracy: 0.8478 - val_loss: 0.5792 - val_accuracy: 0.8136 - lr: 3.0564e-05
#
# Epoch 79: LearningRateScheduler setting learning rate to 2.9035460102022626e-05.
# Epoch 79/200
# 780/780 [==============================] - 52s 66ms/step - loss: 0.4227 - accuracy: 0.8495 - val_loss: 0.5662 - val_accuracy: 0.8176 - lr: 2.9035e-05
#
# Epoch 80: LearningRateScheduler setting learning rate to 2.7583687096921494e-05.
# Epoch 80/200
# 780/780 [==============================] - 50s 64ms/step - loss: 0.4288 - accuracy: 0.8471 - val_loss: 0.5731 - val_accuracy: 0.8155 - lr: 2.7584e-05
#
# Epoch 81: LearningRateScheduler setting learning rate to 2.620450213726144e-05.
# Epoch 81/200
# 780/780 [==============================] - 51s 66ms/step - loss: 0.4285 - accuracy: 0.8498 - val_loss: 0.5633 - val_accuracy: 0.8195 - lr: 2.6205e-05
#
# Epoch 82: LearningRateScheduler setting learning rate to 2.4894276339182395e-05.
# Epoch 82/200
# 780/780 [==============================] - 51s 65ms/step - loss: 0.4225 - accuracy: 0.8482 - val_loss: 0.5644 - val_accuracy: 0.8213 - lr: 2.4894e-05
#
# Epoch 83: LearningRateScheduler setting learning rate to 2.3649562263017287e-05.
# Epoch 83/200
# 780/780 [==============================] - 49s 63ms/step - loss: 0.4196 - accuracy: 0.8523 - val_loss: 0.5685 - val_accuracy: 0.8181 - lr: 2.3650e-05
#
# Epoch 84: LearningRateScheduler setting learning rate to 2.2467083545052444e-05.
# Epoch 84/200
# 780/780 [==============================] - 50s 64ms/step - loss: 0.4182 - accuracy: 0.8531 - val_loss: 0.5584 - val_accuracy: 0.8218 - lr: 2.2467e-05
#
# Epoch 85: LearningRateScheduler setting learning rate to 2.134372971340781e-05.
# Epoch 85/200
# 780/780 [==============================] - 49s 63ms/step - loss: 0.4238 - accuracy: 0.8519 - val_loss: 0.5724 - val_accuracy: 0.8189 - lr: 2.1344e-05
#
# Epoch 86: LearningRateScheduler setting learning rate to 2.0276544091757387e-05.
# Epoch 86/200
# 780/780 [==============================] - 50s 64ms/step - loss: 0.4130 - accuracy: 0.8528 - val_loss: 0.5750 - val_accuracy: 0.8215 - lr: 2.0277e-05
#
# Epoch 87: LearningRateScheduler setting learning rate to 1.9262716887169517e-05.
# Epoch 87/200
# 780/780 [==============================] - 52s 66ms/step - loss: 0.4115 - accuracy: 0.8532 - val_loss: 0.5680 - val_accuracy: 0.8203 - lr: 1.9263e-05
#
# Epoch 88: LearningRateScheduler setting learning rate to 1.8299581734027014e-05.
# Epoch 88/200
# 780/780 [==============================] - 50s 63ms/step - loss: 0.4067 - accuracy: 0.8555 - val_loss: 0.5635 - val_accuracy: 0.8213 - lr: 1.8300e-05
#
# Epoch 89: LearningRateScheduler setting learning rate to 1.7384601869707693e-05.
# Epoch 89/200
# 780/780 [==============================] - 50s 64ms/step - loss: 0.4079 - accuracy: 0.8550 - val_loss: 0.5689 - val_accuracy: 0.8218 - lr: 1.7385e-05
#
# Epoch 90: LearningRateScheduler setting learning rate to 1.6515371862624305e-05.
# Epoch 90/200
# 780/780 [==============================] - 51s 65ms/step - loss: 0.4113 - accuracy: 0.8550 - val_loss: 0.5765 - val_accuracy: 0.8179 - lr: 1.6515e-05
#
# Epoch 91: LearningRateScheduler setting learning rate to 1.568960378790507e-05.
# Epoch 91/200
# 780/780 [==============================] - 49s 63ms/step - loss: 0.4146 - accuracy: 0.8520 - val_loss: 0.5597 - val_accuracy: 0.8223 - lr: 1.5690e-05
#
# Epoch 92: LearningRateScheduler setting learning rate to 1.490512377131381e-05.
# Epoch 92/200
# 780/780 [==============================] - 50s 64ms/step - loss: 0.4035 - accuracy: 0.8561 - val_loss: 0.5631 - val_accuracy: 0.8228 - lr: 1.4905e-05
#
# Epoch 93: LearningRateScheduler setting learning rate to 1.4159867669150115e-05.
# Epoch 93/200
# 780/780 [==============================] - 50s 64ms/step - loss: 0.4123 - accuracy: 0.8565 - val_loss: 0.5662 - val_accuracy: 0.8208 - lr: 1.4160e-05
#
# Epoch 94: LearningRateScheduler setting learning rate to 1.3451874156089615e-05.
# Epoch 94/200
# 780/780 [==============================] - ETA: 0s - loss: 0.4032 - accuracy: 0.8575Restoring model weights from the end of the best epoch: 84.
# 780/780 [==============================] - 51s 65ms/step - loss: 0.4032 - accuracy: 0.8575 - val_loss: 0.5678 - val_accuracy: 0.8200 - lr: 1.3452e-05
# Epoch 94: early stopping

# %%
# 학습 및 검증 정확도와 손실을 그래프로 표시
def plot_history(history):
    plt.figure(figsize=(12, 4))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.legend()
    plt.title('Training and Validation Accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.legend()
    plt.title('Training and Validation Loss')

    plt.show()

# 모델 학습 이후에 이 함수를 호출
plot_history(history)

# %%
# 모델을 사용하여 예측한 클래스와 실제 클래스를 비교하는 이미지 시각화
def plot_predictions(images, labels, predictions, class_names, num=30, images_per_row=10):
    num_rows = (num + images_per_row - 1) // images_per_row
    plt.figure(figsize=(15, 5 * num_rows))
    for i in range(num):
        plt.subplot(num_rows, images_per_row, i + 1)
        plt.imshow(images[i])

        actual_class = class_names[labels[i][0]]
        predicted_class = class_names[np.argmax(predictions[i])]

        title = f"Actual: {actual_class}\nPredicted: {predicted_class}"
        if actual_class != predicted_class:
            title = f"Actual: {actual_class}\nPredicted: {predicted_class}"
            plt.title(title, color='red')  # 예측이 틀린 경우 빨간색 글자로 표시
        else:
            plt.title(title)

        plt.axis('off')

    plt.tight_layout()
    plt.show()

# 모델을 사용하여 예측
predictions = model.predict(resized_test_images)

# 첫 30개 이미지에 대한 실제 클래스와 예측 클래스 시각화
plot_predictions(test_images, test_labels, predictions, class_names, num=30, images_per_row=10)
# Out:
# 313/313 [==============================] - 4s 11ms/step
